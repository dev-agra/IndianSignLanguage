# %%
import os

# %%
CUSTOM_MODEL_NAME = 'my_ssd_mobnet_finalsign' 
PRETRAINED_MODEL_NAME = 'ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8'
PRETRAINED_MODEL_URL = 'http://download.tensorflow.org/models/object_detection/tf2/20200711/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz'
TF_RECORD_SCRIPT_NAME = 'generate_tfrecord.py'
LABEL_MAP_NAME = 'label_map.pbtxt'

# %%
paths = {
    'WORKSPACE_PATH': os.path.join('Tensorflow', 'workspace'),
    'SCRIPTS_PATH': os.path.join('Tensorflow','scripts'),
    'APIMODEL_PATH': os.path.join('Tensorflow','models'),
    'ANNOTATION_PATH': os.path.join('Tensorflow', 'workspace','annotations'),
    'IMAGE_PATH': os.path.join('Tensorflow', 'workspace','images'),
    'MODEL_PATH': os.path.join('Tensorflow', 'workspace','models'),
    'PRETRAINED_MODEL_PATH': os.path.join('Tensorflow', 'workspace','pre-trained-models'),
    'CHECKPOINT_PATH': os.path.join('Tensorflow', 'workspace','models',CUSTOM_MODEL_NAME), 
    'OUTPUT_PATH': os.path.join('Tensorflow', 'workspace','models',CUSTOM_MODEL_NAME, 'export'), 
    'TFJS_PATH':os.path.join('Tensorflow', 'workspace','models',CUSTOM_MODEL_NAME, 'tfjsexport'), 
    'TFLITE_PATH':os.path.join('Tensorflow', 'workspace','models',CUSTOM_MODEL_NAME, 'tfliteexport'), 
    'PROTOC_PATH':os.path.join('Tensorflow','protoc')
 }

# %%
files = {
    'PIPELINE_CONFIG':os.path.join('Tensorflow', 'workspace','models', CUSTOM_MODEL_NAME, 'pipeline.config'),
    'TF_RECORD_SCRIPT': os.path.join(paths['SCRIPTS_PATH'], TF_RECORD_SCRIPT_NAME), 
    'LABELMAP': os.path.join(paths['ANNOTATION_PATH'], LABEL_MAP_NAME)
}

# %%
for path in paths.values():
    if not os.path.exists(path):
        if os.name == 'posix':
            # !mkdir -p {path}
        if os.name == 'nt':
            # !mkdir {path}

# %%
# if os.name=='nt':
#     !pip install wget
import wget

# %%
if not os.path.exists(os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection')):
    # !git clone https://github.com/tensorflow/models {paths['APIMODEL_PATH']}

# %%
# Yaha se karna hain
# Install Tensorflow Object Detection 
if os.name=='posix':  
    # !apt-get install protobuf-compiler
    # !cd Tensorflow/models/research && protoc object_detection/protos/*.proto --python_out=. && cp object_detection/packages/tf2/setup.py . && python -m pip install . 
    
if os.name=='nt':
    url="https://github.com/protocolbuffers/protobuf/releases/download/v3.15.6/protoc-3.15.6-win64.zip"
    wget.download(url)
    # !move protoc-3.15.6-win64.zip {paths['PROTOC_PATH']}
    # !cd {paths['PROTOC_PATH']} && tar -xf protoc-3.15.6-win64.zip
    os.environ['PATH'] += os.pathsep + os.path.abspath(os.path.join(paths['PROTOC_PATH'], 'bin'))   
    # !cd Tensorflow/models/research && protoc object_detection/protos/*.proto --python_out=. && copy object_detection\\packages\\tf2\\setup.py setup.py && python setup.py build && python setup.py install
    # !cd Tensorflow/models/research/slim && pip install -e .

# %%
VERIFICATION_SCRIPT = os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection', 'builders', 'model_builder_tf2_test.py')
# Verify Installation
# !python {VERIFICATION_SCRIPT}
# Out:
# Running tests under Python 3.8.8: C:\Users\Devansh\AppData\Local\Programs\Python\Python38\python.exe
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_deepmac
# 2022-05-13 01:45:19.803448: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX AVX2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-05-13 01:45:20.257676: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2147 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1650 Ti, pci bus id: 0000:01:00.0, compute capability: 7.5
# C:\Users\Devansh\AppData\Local\Programs\Python\Python38\lib\site-packages\object_detection-0.1-py3.8.egg\object_detection\builders\model_builder.py:1100: DeprecationWarning: The 'warn' function is deprecated, use 'warning' instead
#   logging.warn(('Building experimental DeepMAC meta-arch.'
# W0513 01:45:20.483168 17960 model_builder.py:1100] Building experimental DeepMAC meta-arch. Some features may be omitted.
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_deepmac): 0.83s
# I0513 01:45:20.632201 17960 test_util.py:2308] time(__main__.ModelBuilderTF2Test.test_create_center_net_deepmac): 0.83s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_deepmac
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)): 0.86s
# I0513 01:45:21.495434 17960 test_util.py:2308] time(__main__.ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)): 0.86s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)): 0.16s
# I0513 01:45:21.655470 17960 test_util.py:2308] time(__main__.ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)): 0.16s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model_from_keypoints
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model_from_keypoints): 0.15s
# I0513 01:45:21.802497 17960 test_util.py:2308] time(__main__.ModelBuilderTF2Test.test_create_center_net_model_from_keypoints): 0.15s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model_from_keypoints
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model_mobilenet
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model_mobilenet): 1.23s
# I0513 01:45:23.034781 17960 test_util.py:2308] time(__main__.ModelBuilderTF2Test.test_create_center_net_model_mobilenet): 1.23s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model_mobilenet
# [ RUN      ] ModelBuilderTF2Test.test_create_experimental_model
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_experimental_model): 0.0s
# I0513 01:45:23.035781 17960 test_util.py:2308] time(__main__.ModelBuilderTF2Test.test_create_experimental_model): 0.0s
# [       OK ] ModelBuilderTF2Test.test_create_experimental_model
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)): 0.02s
# I0513 01:45:23.051785 17960 test_util.py:2308] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)): 0.02s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)): 0.01s
# I0513 01:45:23.060787 17960 test_util.py:2308] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)): 0.01s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner): 0.01s
# I0513 01:45:23.070789 17960 test_util.py:2308] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner): 0.01s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul): 0.06s
# I0513 01:45:23.133803 17960 test_util.py:2308] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul): 0.06s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul): 0.06s
# I0513 01:45:23.191816 17960 test_util.py:2308] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul): 0.06s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul): 0.06s
# I0513 01:45:23.253824 17960 test_util.py:2308] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul): 0.06s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul): 0.06s
# I0513 01:45:23.314837 17960 test_util.py:2308] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul): 0.06s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_rfcn_model_from_config
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_rfcn_model_from_config): 0.06s
# I0513 01:45:23.373857 17960 test_util.py:2308] time(__main__.ModelBuilderTF2Test.test_create_rfcn_model_from_config): 0.06s
# [       OK ] ModelBuilderTF2Test.test_create_rfcn_model_from_config
# [ RUN      ] ModelBuilderTF2Test.test_create_ssd_fpn_model_from_config
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_ssd_fpn_model_from_config): 0.02s
# I0513 01:45:23.390861 17960 test_util.py:2308] time(__main__.ModelBuilderTF2Test.test_create_ssd_fpn_model_from_config): 0.02s
# [       OK ] ModelBuilderTF2Test.test_create_ssd_fpn_model_from_config
# [ RUN      ] ModelBuilderTF2Test.test_create_ssd_models_from_config
# I0513 01:45:23.502887 17960 ssd_efficientnet_bifpn_feature_extractor.py:145] EfficientDet EfficientNet backbone version: efficientnet-b0
# I0513 01:45:23.502887 17960 ssd_efficientnet_bifpn_feature_extractor.py:147] EfficientDet BiFPN num filters: 64
# I0513 01:45:23.502887 17960 ssd_efficientnet_bifpn_feature_extractor.py:148] EfficientDet BiFPN num iterations: 3
# I0513 01:45:23.504887 17960 efficientnet_model.py:144] round_filter input=32 output=32
# I0513 01:45:23.516877 17960 efficientnet_model.py:144] round_filter input=32 output=32
# I0513 01:45:23.516877 17960 efficientnet_model.py:144] round_filter input=16 output=16
# I0513 01:45:23.560899 17960 efficientnet_model.py:144] round_filter input=16 output=16
# I0513 01:45:23.560899 17960 efficientnet_model.py:144] round_filter input=24 output=24
# I0513 01:45:23.666917 17960 efficientnet_model.py:144] round_filter input=24 output=24
# I0513 01:45:23.666917 17960 efficientnet_model.py:144] round_filter input=40 output=40
# I0513 01:45:23.770946 17960 efficientnet_model.py:144] round_filter input=40 output=40
# I0513 01:45:23.770946 17960 efficientnet_model.py:144] round_filter input=80 output=80
# I0513 01:45:23.928982 17960 efficientnet_model.py:144] round_filter input=80 output=80
# I0513 01:45:23.928982 17960 efficientnet_model.py:144] round_filter input=112 output=112
# I0513 01:45:24.087018 17960 efficientnet_model.py:144] round_filter input=112 output=112
# I0513 01:45:24.087018 17960 efficientnet_model.py:144] round_filter input=192 output=192
# I0513 01:45:24.399076 17960 efficientnet_model.py:144] round_filter input=192 output=192
# I0513 01:45:24.399076 17960 efficientnet_model.py:144] round_filter input=320 output=320
# I0513 01:45:24.451100 17960 efficientnet_model.py:144] round_filter input=1280 output=1280
# I0513 01:45:24.474098 17960 efficientnet_model.py:454] Building model efficientnet with params ModelConfig(width_coefficient=1.0, depth_coefficient=1.0, resolution=224, dropout_rate=0.2, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0513 01:45:24.508108 17960 ssd_efficientnet_bifpn_feature_extractor.py:145] EfficientDet EfficientNet backbone version: efficientnet-b1
# I0513 01:45:24.508108 17960 ssd_efficientnet_bifpn_feature_extractor.py:147] EfficientDet BiFPN num filters: 88
# I0513 01:45:24.508108 17960 ssd_efficientnet_bifpn_feature_extractor.py:148] EfficientDet BiFPN num iterations: 4
# I0513 01:45:24.509093 17960 efficientnet_model.py:144] round_filter input=32 output=32
# I0513 01:45:24.525098 17960 efficientnet_model.py:144] round_filter input=32 output=32
# I0513 01:45:24.525098 17960 efficientnet_model.py:144] round_filter input=16 output=16
# I0513 01:45:24.642123 17960 efficientnet_model.py:144] round_filter input=16 output=16
# I0513 01:45:24.642123 17960 efficientnet_model.py:144] round_filter input=24 output=24
# I0513 01:45:24.807180 17960 efficientnet_model.py:144] round_filter input=24 output=24
# I0513 01:45:24.807180 17960 efficientnet_model.py:144] round_filter input=40 output=40
# I0513 01:45:24.962215 17960 efficientnet_model.py:144] round_filter input=40 output=40
# I0513 01:45:24.962215 17960 efficientnet_model.py:144] round_filter input=80 output=80
# I0513 01:45:25.170255 17960 efficientnet_model.py:144] round_filter input=80 output=80
# I0513 01:45:25.170255 17960 efficientnet_model.py:144] round_filter input=112 output=112
# I0513 01:45:25.377308 17960 efficientnet_model.py:144] round_filter input=112 output=112
# I0513 01:45:25.378309 17960 efficientnet_model.py:144] round_filter input=192 output=192
# I0513 01:45:25.638367 17960 efficientnet_model.py:144] round_filter input=192 output=192
# I0513 01:45:25.638367 17960 efficientnet_model.py:144] round_filter input=320 output=320
# I0513 01:45:25.744391 17960 efficientnet_model.py:144] round_filter input=1280 output=1280
# I0513 01:45:25.764389 17960 efficientnet_model.py:454] Building model efficientnet with params ModelConfig(width_coefficient=1.0, depth_coefficient=1.1, resolution=240, dropout_rate=0.2, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0513 01:45:25.805405 17960 ssd_efficientnet_bifpn_feature_extractor.py:145] EfficientDet EfficientNet backbone version: efficientnet-b2
# I0513 01:45:25.805405 17960 ssd_efficientnet_bifpn_feature_extractor.py:147] EfficientDet BiFPN num filters: 112
# I0513 01:45:25.805405 17960 ssd_efficientnet_bifpn_feature_extractor.py:148] EfficientDet BiFPN num iterations: 5
# I0513 01:45:25.806405 17960 efficientnet_model.py:144] round_filter input=32 output=32
# I0513 01:45:25.817395 17960 efficientnet_model.py:144] round_filter input=32 output=32
# I0513 01:45:25.817395 17960 efficientnet_model.py:144] round_filter input=16 output=16
# I0513 01:45:25.900426 17960 efficientnet_model.py:144] round_filter input=16 output=16
# I0513 01:45:25.900426 17960 efficientnet_model.py:144] round_filter input=24 output=24
# I0513 01:45:26.056461 17960 efficientnet_model.py:144] round_filter input=24 output=24
# I0513 01:45:26.056461 17960 efficientnet_model.py:144] round_filter input=40 output=48
# I0513 01:45:26.213497 17960 efficientnet_model.py:144] round_filter input=40 output=48
# I0513 01:45:26.213497 17960 efficientnet_model.py:144] round_filter input=80 output=88
# I0513 01:45:26.425542 17960 efficientnet_model.py:144] round_filter input=80 output=88
# I0513 01:45:26.425542 17960 efficientnet_model.py:144] round_filter input=112 output=120
# I0513 01:45:26.636592 17960 efficientnet_model.py:144] round_filter input=112 output=120
# I0513 01:45:26.636592 17960 efficientnet_model.py:144] round_filter input=192 output=208
# I0513 01:45:27.009676 17960 efficientnet_model.py:144] round_filter input=192 output=208
# I0513 01:45:27.010676 17960 efficientnet_model.py:144] round_filter input=320 output=352
# I0513 01:45:27.115687 17960 efficientnet_model.py:144] round_filter input=1280 output=1408
# I0513 01:45:27.136698 17960 efficientnet_model.py:454] Building model efficientnet with params ModelConfig(width_coefficient=1.1, depth_coefficient=1.2, resolution=260, dropout_rate=0.3, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0513 01:45:27.177713 17960 ssd_efficientnet_bifpn_feature_extractor.py:145] EfficientDet EfficientNet backbone version: efficientnet-b3
# I0513 01:45:27.177713 17960 ssd_efficientnet_bifpn_feature_extractor.py:147] EfficientDet BiFPN num filters: 160
# I0513 01:45:27.177713 17960 ssd_efficientnet_bifpn_feature_extractor.py:148] EfficientDet BiFPN num iterations: 6
# I0513 01:45:27.179714 17960 efficientnet_model.py:144] round_filter input=32 output=40
# I0513 01:45:27.190716 17960 efficientnet_model.py:144] round_filter input=32 output=40
# I0513 01:45:27.190716 17960 efficientnet_model.py:144] round_filter input=16 output=24
# I0513 01:45:27.271722 17960 efficientnet_model.py:144] round_filter input=16 output=24
# I0513 01:45:27.272735 17960 efficientnet_model.py:144] round_filter input=24 output=32
# I0513 01:45:27.432767 17960 efficientnet_model.py:144] round_filter input=24 output=32
# I0513 01:45:27.432767 17960 efficientnet_model.py:144] round_filter input=40 output=48
# I0513 01:45:27.594803 17960 efficientnet_model.py:144] round_filter input=40 output=48
# I0513 01:45:27.594803 17960 efficientnet_model.py:144] round_filter input=80 output=96
# I0513 01:45:27.867866 17960 efficientnet_model.py:144] round_filter input=80 output=96
# I0513 01:45:27.867866 17960 efficientnet_model.py:144] round_filter input=112 output=136
# I0513 01:45:28.138930 17960 efficientnet_model.py:144] round_filter input=112 output=136
# I0513 01:45:28.139930 17960 efficientnet_model.py:144] round_filter input=192 output=232
# I0513 01:45:28.460996 17960 efficientnet_model.py:144] round_filter input=192 output=232
# I0513 01:45:28.460996 17960 efficientnet_model.py:144] round_filter input=320 output=384
# I0513 01:45:28.567014 17960 efficientnet_model.py:144] round_filter input=1280 output=1536
# I0513 01:45:28.589025 17960 efficientnet_model.py:454] Building model efficientnet with params ModelConfig(width_coefficient=1.2, depth_coefficient=1.4, resolution=300, dropout_rate=0.3, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0513 01:45:28.633041 17960 ssd_efficientnet_bifpn_feature_extractor.py:145] EfficientDet EfficientNet backbone version: efficientnet-b4
# I0513 01:45:28.634041 17960 ssd_efficientnet_bifpn_feature_extractor.py:147] EfficientDet BiFPN num filters: 224
# I0513 01:45:28.634041 17960 ssd_efficientnet_bifpn_feature_extractor.py:148] EfficientDet BiFPN num iterations: 7
# I0513 01:45:28.635041 17960 efficientnet_model.py:144] round_filter input=32 output=48
# I0513 01:45:28.648041 17960 efficientnet_model.py:144] round_filter input=32 output=48
# I0513 01:45:28.648041 17960 efficientnet_model.py:144] round_filter input=16 output=24
# I0513 01:45:28.733054 17960 efficientnet_model.py:144] round_filter input=16 output=24
# I0513 01:45:28.733054 17960 efficientnet_model.py:144] round_filter input=24 output=32
# I0513 01:45:28.951110 17960 efficientnet_model.py:144] round_filter input=24 output=32
# I0513 01:45:28.951110 17960 efficientnet_model.py:144] round_filter input=40 output=56
# I0513 01:45:29.168159 17960 efficientnet_model.py:144] round_filter input=40 output=56
# I0513 01:45:29.168159 17960 efficientnet_model.py:144] round_filter input=80 output=112
# I0513 01:45:29.495233 17960 efficientnet_model.py:144] round_filter input=80 output=112
# I0513 01:45:29.496233 17960 efficientnet_model.py:144] round_filter input=112 output=160
# I0513 01:45:29.877302 17960 efficientnet_model.py:144] round_filter input=112 output=160
# I0513 01:45:29.877302 17960 efficientnet_model.py:144] round_filter input=192 output=272
# I0513 01:45:30.474435 17960 efficientnet_model.py:144] round_filter input=192 output=272
# I0513 01:45:30.474435 17960 efficientnet_model.py:144] round_filter input=320 output=448
# I0513 01:45:30.586468 17960 efficientnet_model.py:144] round_filter input=1280 output=1792
# I0513 01:45:30.608473 17960 efficientnet_model.py:454] Building model efficientnet with params ModelConfig(width_coefficient=1.4, depth_coefficient=1.8, resolution=380, dropout_rate=0.4, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0513 01:45:30.662492 17960 ssd_efficientnet_bifpn_feature_extractor.py:145] EfficientDet EfficientNet backbone version: efficientnet-b5
# I0513 01:45:30.662492 17960 ssd_efficientnet_bifpn_feature_extractor.py:147] EfficientDet BiFPN num filters: 288
# I0513 01:45:30.662492 17960 ssd_efficientnet_bifpn_feature_extractor.py:148] EfficientDet BiFPN num iterations: 7
# I0513 01:45:30.663493 17960 efficientnet_model.py:144] round_filter input=32 output=48
# I0513 01:45:30.675495 17960 efficientnet_model.py:144] round_filter input=32 output=48
# I0513 01:45:30.675495 17960 efficientnet_model.py:144] round_filter input=16 output=24
# I0513 01:45:30.802509 17960 efficientnet_model.py:144] round_filter input=16 output=24
# I0513 01:45:30.802509 17960 efficientnet_model.py:144] round_filter input=24 output=40
# I0513 01:45:31.081580 17960 efficientnet_model.py:144] round_filter input=24 output=40
# I0513 01:45:31.081580 17960 efficientnet_model.py:144] round_filter input=40 output=64
# I0513 01:45:31.351634 17960 efficientnet_model.py:144] round_filter input=40 output=64
# I0513 01:45:31.351634 17960 efficientnet_model.py:144] round_filter input=80 output=128
# I0513 01:45:31.736740 17960 efficientnet_model.py:144] round_filter input=80 output=128
# I0513 01:45:31.736740 17960 efficientnet_model.py:144] round_filter input=112 output=176
# I0513 01:45:32.116812 17960 efficientnet_model.py:144] round_filter input=112 output=176
# I0513 01:45:32.116812 17960 efficientnet_model.py:144] round_filter input=192 output=304
# I0513 01:45:32.595933 17960 efficientnet_model.py:144] round_filter input=192 output=304
# I0513 01:45:32.595933 17960 efficientnet_model.py:144] round_filter input=320 output=512
# I0513 01:45:32.753969 17960 efficientnet_model.py:144] round_filter input=1280 output=2048
# I0513 01:45:32.774973 17960 efficientnet_model.py:454] Building model efficientnet with params ModelConfig(width_coefficient=1.6, depth_coefficient=2.2, resolution=456, dropout_rate=0.4, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0513 01:45:32.835987 17960 ssd_efficientnet_bifpn_feature_extractor.py:145] EfficientDet EfficientNet backbone version: efficientnet-b6
# I0513 01:45:32.836987 17960 ssd_efficientnet_bifpn_feature_extractor.py:147] EfficientDet BiFPN num filters: 384
# I0513 01:45:32.836987 17960 ssd_efficientnet_bifpn_feature_extractor.py:148] EfficientDet BiFPN num iterations: 8
# I0513 01:45:32.837988 17960 efficientnet_model.py:144] round_filter input=32 output=56
# I0513 01:45:32.849990 17960 efficientnet_model.py:144] round_filter input=32 output=56
# I0513 01:45:32.849990 17960 efficientnet_model.py:144] round_filter input=16 output=32
# I0513 01:45:32.973018 17960 efficientnet_model.py:144] round_filter input=16 output=32
# I0513 01:45:32.974018 17960 efficientnet_model.py:144] round_filter input=24 output=40
# I0513 01:45:33.286089 17960 efficientnet_model.py:144] round_filter input=24 output=40
# I0513 01:45:33.286089 17960 efficientnet_model.py:144] round_filter input=40 output=72
# I0513 01:45:33.788202 17960 efficientnet_model.py:144] round_filter input=40 output=72
# I0513 01:45:33.788202 17960 efficientnet_model.py:144] round_filter input=80 output=144
# I0513 01:45:34.207296 17960 efficientnet_model.py:144] round_filter input=80 output=144
# I0513 01:45:34.208296 17960 efficientnet_model.py:144] round_filter input=112 output=200
# I0513 01:45:34.643394 17960 efficientnet_model.py:144] round_filter input=112 output=200
# I0513 01:45:34.643394 17960 efficientnet_model.py:144] round_filter input=192 output=344
# I0513 01:45:35.273523 17960 efficientnet_model.py:144] round_filter input=192 output=344
# I0513 01:45:35.274536 17960 efficientnet_model.py:144] round_filter input=320 output=576
# I0513 01:45:35.430560 17960 efficientnet_model.py:144] round_filter input=1280 output=2304
# I0513 01:45:35.451576 17960 efficientnet_model.py:454] Building model efficientnet with params ModelConfig(width_coefficient=1.8, depth_coefficient=2.6, resolution=528, dropout_rate=0.5, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0513 01:45:35.520592 17960 ssd_efficientnet_bifpn_feature_extractor.py:145] EfficientDet EfficientNet backbone version: efficientnet-b7
# I0513 01:45:35.520592 17960 ssd_efficientnet_bifpn_feature_extractor.py:147] EfficientDet BiFPN num filters: 384
# I0513 01:45:35.520592 17960 ssd_efficientnet_bifpn_feature_extractor.py:148] EfficientDet BiFPN num iterations: 8
# I0513 01:45:35.521592 17960 efficientnet_model.py:144] round_filter input=32 output=64
# I0513 01:45:35.532594 17960 efficientnet_model.py:144] round_filter input=32 output=64
# I0513 01:45:35.532594 17960 efficientnet_model.py:144] round_filter input=16 output=32
# I0513 01:45:35.700632 17960 efficientnet_model.py:144] round_filter input=16 output=32
# I0513 01:45:35.700632 17960 efficientnet_model.py:144] round_filter input=24 output=48
# I0513 01:45:36.064701 17960 efficientnet_model.py:144] round_filter input=24 output=48
# I0513 01:45:36.064701 17960 efficientnet_model.py:144] round_filter input=40 output=80
# I0513 01:45:36.429777 17960 efficientnet_model.py:144] round_filter input=40 output=80
# I0513 01:45:36.429777 17960 efficientnet_model.py:144] round_filter input=80 output=160
# I0513 01:45:36.955902 17960 efficientnet_model.py:144] round_filter input=80 output=160
# I0513 01:45:36.955902 17960 efficientnet_model.py:144] round_filter input=112 output=224
# I0513 01:45:37.659060 17960 efficientnet_model.py:144] round_filter input=112 output=224
# I0513 01:45:37.659060 17960 efficientnet_model.py:144] round_filter input=192 output=384
# I0513 01:45:38.339226 17960 efficientnet_model.py:144] round_filter input=192 output=384
# I0513 01:45:38.339226 17960 efficientnet_model.py:144] round_filter input=320 output=640
# I0513 01:45:38.550267 17960 efficientnet_model.py:144] round_filter input=1280 output=2560
# I0513 01:45:38.570278 17960 efficientnet_model.py:454] Building model efficientnet with params ModelConfig(width_coefficient=2.0, depth_coefficient=3.1, resolution=600, dropout_rate=0.5, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_ssd_models_from_config): 15.26s
# I0513 01:45:38.655297 17960 test_util.py:2308] time(__main__.ModelBuilderTF2Test.test_create_ssd_models_from_config): 15.26s
# [       OK ] ModelBuilderTF2Test.test_create_ssd_models_from_config
# [ RUN      ] ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update): 0.0s
# I0513 01:45:38.659298 17960 test_util.py:2308] time(__main__.ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update
# [ RUN      ] ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold): 0.0s
# I0513 01:45:38.660298 17960 test_util.py:2308] time(__main__.ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold
# [ RUN      ] ModelBuilderTF2Test.test_invalid_model_config_proto
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_model_config_proto): 0.0s
# I0513 01:45:38.660298 17960 test_util.py:2308] time(__main__.ModelBuilderTF2Test.test_invalid_model_config_proto): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_model_config_proto
# [ RUN      ] ModelBuilderTF2Test.test_invalid_second_stage_batch_size
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_second_stage_batch_size): 0.0s
# I0513 01:45:38.661299 17960 test_util.py:2308] time(__main__.ModelBuilderTF2Test.test_invalid_second_stage_batch_size): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_second_stage_batch_size
# [ RUN      ] ModelBuilderTF2Test.test_session
# [  SKIPPED ] ModelBuilderTF2Test.test_session
# [ RUN      ] ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor): 0.0s
# I0513 01:45:38.662292 17960 test_util.py:2308] time(__main__.ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor): 0.0s
# [       OK ] ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor
# [ RUN      ] ModelBuilderTF2Test.test_unknown_meta_architecture
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_unknown_meta_architecture): 0.0s
# I0513 01:45:38.663293 17960 test_util.py:2308] time(__main__.ModelBuilderTF2Test.test_unknown_meta_architecture): 0.0s
# [       OK ] ModelBuilderTF2Test.test_unknown_meta_architecture
# [ RUN      ] ModelBuilderTF2Test.test_unknown_ssd_feature_extractor
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_unknown_ssd_feature_extractor): 0.0s
# I0513 01:45:38.663293 17960 test_util.py:2308] time(__main__.ModelBuilderTF2Test.test_unknown_ssd_feature_extractor): 0.0s
# [       OK ] ModelBuilderTF2Test.test_unknown_ssd_feature_extractor
# ----------------------------------------------------------------------
# Ran 24 tests in 18.864s
#
# OK (skipped=1)

# %%
# !pip install pyparsing==2.4.2
# Out:
# Requirement already satisfied: pyparsing==2.4.2 in c:\users\devansh\appdata\local\programs\python\python38\lib\site-packages (2.4.2)
# WARNING: You are using pip version 22.0.4; however, version 22.1 is available.
# You should consider upgrading via the 'c:\users\devansh\appdata\local\programs\python\python38\python.exe -m pip install --upgrade pip' command.

# %%
import object_detection

# %%
# !pip install tensorflow==2.7.0
# Out:
# Requirement already satisfied: tensorflow==2.7.0 in c:\programming\hackathon-2022\hackathon\lib\site-packages (2.7.0)
# WARNING: You are using pip version 22.0.4; however, version 22.1 is available.
# You should consider upgrading via the 'c:\programming\hackathon-2022\hackathon\scripts\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\programming\hackathon-2022\hackathon\lib\site-packages (from tensorflow==2.7.0) (1.1.2)
# Requirement already satisfied: protobuf>=3.9.2 in c:\programming\hackathon-2022\hackathon\lib\site-packages (from tensorflow==2.7.0) (3.19.4)
# Requirement already satisfied: astunparse>=1.6.0 in c:\programming\hackathon-2022\hackathon\lib\site-packages (from tensorflow==2.7.0) (1.6.3)
# Requirement already satisfied: six>=1.12.0 in c:\programming\hackathon-2022\hackathon\lib\site-packages (from tensorflow==2.7.0) (1.16.0)
# Requirement already satisfied: gast<0.5.0,>=0.2.1 in c:\programming\hackathon-2022\hackathon\lib\site-packages (from tensorflow==2.7.0) (0.4.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\programming\hackathon-2022\hackathon\lib\site-packages (from tensorflow==2.7.0) (3.3.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\programming\hackathon-2022\hackathon\lib\site-packages (from tensorflow==2.7.0) (1.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\programming\hackathon-2022\hackathon\lib\site-packages\typing_extensions-4.1.1-py3.8.egg (from tensorflow==2.7.0) (4.1.1)
# Requirement already satisfied: numpy>=1.14.5 in c:\programming\hackathon-2022\hackathon\lib\site-packages (from tensorflow==2.7.0) (1.22.3)
# Requirement already satisfied: keras<2.8,>=2.7.0rc0 in c:\programming\hackathon-2022\hackathon\lib\site-packages (from tensorflow==2.7.0) (2.7.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\programming\hackathon-2022\hackathon\lib\site-packages (from tensorflow==2.7.0) (1.14.0)
# Requirement already satisfied: flatbuffers<3.0,>=1.12 in c:\programming\hackathon-2022\hackathon\lib\site-packages (from tensorflow==2.7.0) (2.0)
# Requirement already satisfied: tensorflow-estimator<2.8,~=2.7.0rc0 in c:\programming\hackathon-2022\hackathon\lib\site-packages (from tensorflow==2.7.0) (2.7.0)
# Requirement already satisfied: wheel<1.0,>=0.32.0 in c:\programming\hackathon-2022\hackathon\lib\site-packages (from tensorflow==2.7.0) (0.37.1)
# Requirement already satisfied: absl-py>=0.4.0 in c:\programming\hackathon-2022\hackathon\lib\site-packages\absl_py-1.0.0-py3.8.egg (from tensorflow==2.7.0) (1.0.0)
# Requirement already satisfied: tensorboard~=2.6 in c:\programming\hackathon-2022\hackathon\lib\site-packages (from tensorflow==2.7.0) (2.8.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\programming\hackathon-2022\hackathon\lib\site-packages (from tensorflow==2.7.0) (1.44.0)
# Requirement already satisfied: libclang>=9.0.1 in c:\programming\hackathon-2022\hackathon\lib\site-packages (from tensorflow==2.7.0) (13.0.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.21.0 in c:\programming\hackathon-2022\hackathon\lib\site-packages\tensorflow_io_gcs_filesystem-0.24.0-py3.8-win-amd64.egg (from tensorflow==2.7.0) (0.24.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\programming\hackathon-2022\hackathon\lib\site-packages (from tensorflow==2.7.0) (3.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\programming\hackathon-2022\hackathon\lib\site-packages (from tensorflow==2.7.0) (0.2.0)
# Requirement already satisfied: setuptools>=41.0.0 in c:\programming\hackathon-2022\hackathon\lib\site-packages (from tensorboard~=2.6->tensorflow==2.7.0) (49.2.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\programming\hackathon-2022\hackathon\lib\site-packages (from tensorboard~=2.6->tensorflow==2.7.0) (2.6.0)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\programming\hackathon-2022\hackathon\lib\site-packages\requests-2.27.1-py3.8.egg (from tensorboard~=2.6->tensorflow==2.7.0) (2.27.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\programming\hackathon-2022\hackathon\lib\site-packages (from tensorboard~=2.6->tensorflow==2.7.0) (0.6.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\programming\hackathon-2022\hackathon\lib\site-packages (from tensorboard~=2.6->tensorflow==2.7.0) (0.4.6)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\programming\hackathon-2022\hackathon\lib\site-packages (from tensorboard~=2.6->tensorflow==2.7.0) (1.8.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\programming\hackathon-2022\hackathon\lib\site-packages (from tensorboard~=2.6->tensorflow==2.7.0) (3.3.6)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\programming\hackathon-2022\hackathon\lib\site-packages (from tensorboard~=2.6->tensorflow==2.7.0) (2.0.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\programming\hackathon-2022\hackathon\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow==2.7.0) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\programming\hackathon-2022\hackathon\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow==2.7.0) (5.0.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\programming\hackathon-2022\hackathon\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow==2.7.0) (4.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\programming\hackathon-2022\hackathon\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow==2.7.0) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\programming\hackathon-2022\hackathon\lib\site-packages (from markdown>=2.6.8->tensorboard~=2.6->tensorflow==2.7.0) (4.11.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programming\hackathon-2022\hackathon\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow==2.7.0) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\programming\hackathon-2022\hackathon\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow==2.7.0) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in c:\programming\hackathon-2022\hackathon\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow==2.7.0) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\programming\hackathon-2022\hackathon\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow==2.7.0) (1.26.9)
# Requirement already satisfied: zipp>=0.5 in c:\programming\hackathon-2022\hackathon\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard~=2.6->tensorflow==2.7.0) (3.7.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\programming\hackathon-2022\hackathon\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow==2.7.0) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\programming\hackathon-2022\hackathon\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow==2.7.0) (3.2.0)

# %%
# !pip list
# Out:
# Package                       Version
# ----------------------------- -------------------
# absl-py                       1.0.0
# altgraph                      0.17.2
# apache-beam                   2.38.0
# argon2-cffi                   21.3.0
# argon2-cffi-bindings          21.2.0
# asttokens                     2.0.5
# astunparse                    1.6.3
# attrs                         21.4.0
# avro-python3                  1.10.2
# backcall                      0.2.0
# beautifulsoup4                4.11.1
# bleach                        5.0.0
# cachetools                    5.0.0
# certifi                       2021.10.8
# cffi                          1.15.0
# charset-normalizer            2.0.12
# cloudpickle                   2.0.0
# colorama                      0.4.4
# contextlib2                   21.6.0
# crcmod                        1.7
# cycler                        0.11.0
# Cython                        3.0.0a10
# debugpy                       1.6.0
# decorator                     5.1.1
# defusedxml                    0.7.1
# dill                          0.3.1.1
# dnspython                     1.16.0
# entrypoints                   0.4
# executing                     0.8.3
# fastavro                      1.4.11
# fastjsonschema                2.15.3
# flatbuffers                   2.0
# fonttools                     4.33.3
# future                        0.18.2
# gast                          0.4.0
# gin-config                    0.5.0
# google-api-python-client      2.47.0
# google-auth                   2.6.6
# google-auth-oauthlib          0.4.6
# google-pasta                  0.2.0
# grpcio                        1.46.1
# h5py                          3.6.0
# hdfs                          2.7.0
# httplib2                      0.19.1
# idna                          3.3
# importlib-metadata            4.11.3
# importlib-resources           5.7.1
# ipykernel                     6.13.0
# ipython                       8.3.0
# ipython-genutils              0.2.0
# ipywidgets                    7.7.0
# jedi                          0.18.1
# Jinja2                        3.1.2
# jsonschema                    4.5.1
# jupyter                       1.0.0
# jupyter-client                7.3.1
# jupyter-console               6.4.3
# jupyter-core                  4.10.0
# jupyterlab-pygments           0.2.2
# jupyterlab-widgets            1.1.0
# kaggle                        1.5.12
# keras                         2.7.0
# Keras-Preprocessing           1.1.2
# kiwisolver                    1.4.2
# libclang                      14.0.1
# lvis                          0.5.3
# lxml                          4.8.0
# Markdown                      3.3.7
# MarkupSafe                    2.1.1
# matplotlib                    3.5.2
# matplotlib-inline             0.1.3
# mistune                       0.8.4
# mysql-connector-python        8.0.19
# nbclient                      0.6.3
# nbconvert                     6.5.0
# nbformat                      5.4.0
# nest-asyncio                  1.5.5
# notebook                      6.4.11
# numpy                         1.22.3
# oauth2client                  4.1.3
# oauthlib                      3.2.0
# object-detection              0.1
# opencv-python                 4.5.5.64
# opencv-python-headless        4.5.5.64
# opt-einsum                    3.3.0
# orjson                        3.6.8
# packaging                     21.3
# pandas                        1.4.2
# pandocfilters                 1.5.0
# parso                         0.8.3
# pefile                        2021.9.3
# pickleshare                   0.7.5
# Pillow                        9.1.0
# pip                           22.0.4
# ply                           3.11
# prometheus-client             0.14.1
# prompt-toolkit                3.0.29
# proto-plus                    1.20.3
# protobuf                      3.20.1
# psutil                        5.9.0
# pure-eval                     0.2.2
# py-cpuinfo                    8.0.0
# pyarrow                       6.0.1
# pyasn1                        0.4.8
# pyasn1-modules                0.2.8
# pycocotools                   2.0.4
# pycparser                     2.21
# pydot                         1.4.2
# Pygments                      2.12.0
# pyinstaller                   4.10
# pyinstaller-hooks-contrib     2022.3
# pymongo                       3.12.3
# pyparsing                     2.4.2
# pyperclip                     1.8.2
# pyrsistent                    0.18.1
# python-dateutil               2.8.2
# pytz                          2022.1
# pywin32                       304
# pywin32-ctypes                0.2.0
# pywinpty                      2.0.5
# PyYAML                        5.4.1
# pyzmq                         22.3.0
# qtconsole                     5.3.0
# QtPy                          2.1.0
# requests                      2.27.1
# requests-oauthlib             1.3.1
# rsa                           4.8
# sacrebleu                     2.0.0
# scipy                         1.8.0
# Send2Trash                    1.8.0
# sentencepiece                 0.1.96
# seqeval                       1.2.2
# setuptools                    49.2.1
# sip                           6.6.1
# six                           1.16.0
# soupsieve                     2.3.2.post1
# stack-data                    0.2.0
# tensorboard                   2.8.0
# tensorboard-data-server       0.6.1
# tensorboard-plugin-wit        1.8.1
# tensorflow                    2.7.0
# tensorflow-addons             0.16.1
# tensorflow-datasets           4.5.2
# tensorflow-estimator          2.7.0
# tensorflow-hub                0.12.0
# tensorflow-io                 0.25.0
# tensorflow-io-gcs-filesystem  0.25.0
# tensorflow-model-optimization 0.7.2
# tensorflow-text               2.8.2
# termcolor                     1.1.0
# terminado                     0.13.3
# tf-estimator-nightly          2.8.0.dev2021122109
# tf-models-official            2.8.0
# tf-slim                       1.1.0
# tinycss2                      1.1.1
# toml                          0.10.2
# tornado                       6.1
# traitlets                     5.2.0
# typing_extensions             4.2.0
# urllib3                       1.26.9
# wcwidth                       0.2.5
# webencodings                  0.5.1
# Werkzeug                      2.1.2
# wget                          3.2
# wheel                         0.37.1
# widgetsnbextension            3.6.0
# wrapt                         1.14.1
# zipp                          3.8.0
# WARNING: You are using pip version 22.0.4; however, version 22.1 is available.
# You should consider upgrading via the 'c:\users\devansh\appdata\local\programs\python\python38\python.exe -m pip install --upgrade pip' command.

# %%
if os.name =='posix':
    # !wget {PRETRAINED_MODEL_URL}
    # !mv {PRETRAINED_MODEL_NAME+'.tar.gz'} {paths['PRETRAINED_MODEL_PATH']}
    # !cd {paths['PRETRAINED_MODEL_PATH']} && tar -zxvf {PRETRAINED_MODEL_NAME+'.tar.gz'}
if os.name == 'nt':
    wget.download(PRETRAINED_MODEL_URL)
    # !move {PRETRAINED_MODEL_NAME+'.tar.gz'} {paths['PRETRAINED_MODEL_PATH']}
    # !cd {paths['PRETRAINED_MODEL_PATH']} && tar -zxvf {PRETRAINED_MODEL_NAME+'.tar.gz'}
# Out:
# 100% [........................................................................] 20515344 / 20515344        1 file(s) moved.
# x ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/
# x ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint/
# x ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint/ckpt-0.data-00000-of-00001
# x ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint/checkpoint
# x ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint/ckpt-0.index
# x ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/pipeline.config
# x ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/saved_model/
# x ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/saved_model/saved_model.pb
# x ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/saved_model/variables/
# x ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/saved_model/variables/variables.data-00000-of-00001
# x ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/saved_model/variables/variables.index

# %%
labels = [{'name':'Four', 'id':1}, {'name':'Man', 'id':2}, {'name':'ThumbsDown', 'id':3}, {'name':'ThumbsUp', 'id':4} ]

with open(files['LABELMAP'], 'w') as f:
    for label in labels:
        f.write('item { \n')
        f.write('\tname:\'{}\'\n'.format(label['name']))
        f.write('\tid:{}\n'.format(label['id']))
        f.write('}\n')

# %%
if not os.path.exists(files['TF_RECORD_SCRIPT']):
    # !git clone https://github.com/nicknochnack/GenerateTFRecord {paths['SCRIPTS_PATH']}

# %%
# !python {files['TF_RECORD_SCRIPT']} -x {os.path.join(paths['IMAGE_PATH'], 'train')} -l {files['LABELMAP']} -o {os.path.join(paths['ANNOTATION_PATH'], 'train.record')} 
# !python {files['TF_RECORD_SCRIPT']} -x {os.path.join(paths['IMAGE_PATH'], 'test')} -l {files['LABELMAP']} -o {os.path.join(paths['ANNOTATION_PATH'], 'test.record')}
# Out:
# Successfully created the TFRecord file: Tensorflow\workspace\annotations\train.record
# Successfully created the TFRecord file: Tensorflow\workspace\annotations\test.record

# %%
if os.name =='posix':
    # !cp {os.path.join(paths['PRETRAINED_MODEL_PATH'], PRETRAINED_MODEL_NAME, 'pipeline.config')} {os.path.join(paths['CHECKPOINT_PATH'])}
if os.name == 'nt':
    # !copy {os.path.join(paths['PRETRAINED_MODEL_PATH'], PRETRAINED_MODEL_NAME, 'pipeline.config')} {os.path.join(paths['CHECKPOINT_PATH'])}
# Out:
#         1 file(s) copied.

# %%
import tensorflow as tf
from object_detection.utils import config_util
from object_detection.protos import pipeline_pb2
from google.protobuf import text_format

# %%
config = config_util.get_configs_from_pipeline_file(files['PIPELINE_CONFIG'])

# %%
config
# Out:
# {'model': ssd {
#    num_classes: 90
#    image_resizer {
#      fixed_shape_resizer {
#        height: 320
#        width: 320
#      }
#    }
#    feature_extractor {
#      type: "ssd_mobilenet_v2_fpn_keras"
#      depth_multiplier: 1.0
#      min_depth: 16
#      conv_hyperparams {
#        regularizer {
#          l2_regularizer {
#            weight: 3.9999998989515007e-05
#          }
#        }
#        initializer {
#          random_normal_initializer {
#            mean: 0.0
#            stddev: 0.009999999776482582
#          }
#        }
#        activation: RELU_6
#        batch_norm {
#          decay: 0.996999979019165
#          scale: true
#          epsilon: 0.0010000000474974513
#        }
#      }
#      use_depthwise: true
#      override_base_feature_extractor_hyperparams: true
#      fpn {
#        min_level: 3
#        max_level: 7
#        additional_layer_depth: 128
#      }
#    }
#    box_coder {
#      faster_rcnn_box_coder {
#        y_scale: 10.0
#        x_scale: 10.0
#        height_scale: 5.0
#        width_scale: 5.0
#      }
#    }
#    matcher {
#      argmax_matcher {
#        matched_threshold: 0.5
#        unmatched_threshold: 0.5
#        ignore_thresholds: false
#        negatives_lower_than_unmatched: true
#        force_match_for_each_row: true
#        use_matmul_gather: true
#      }
#    }
#    similarity_calculator {
#      iou_similarity {
#      }
#    }
#    box_predictor {
#      weight_shared_convolutional_box_predictor {
#        conv_hyperparams {
#          regularizer {
#            l2_regularizer {
#              weight: 3.9999998989515007e-05
#            }
#          }
#          initializer {
#            random_normal_initializer {
#              mean: 0.0
#              stddev: 0.009999999776482582
#            }
#          }
#          activation: RELU_6
#          batch_norm {
#            decay: 0.996999979019165
#            scale: true
#            epsilon: 0.0010000000474974513
#          }
#        }
#        depth: 128
#        num_layers_before_predictor: 4
#        kernel_size: 3
#        class_prediction_bias_init: -4.599999904632568
#        share_prediction_tower: true
#        use_depthwise: true
#      }
#    }
#    anchor_generator {
#      multiscale_anchor_generator {
#        min_level: 3
#        max_level: 7
#        anchor_scale: 4.0
#        aspect_ratios: 1.0
#        aspect_ratios: 2.0
#        aspect_ratios: 0.5
#        scales_per_octave: 2
#      }
#    }
#    post_processing {
#      batch_non_max_suppression {
#        score_threshold: 9.99999993922529e-09
#        iou_threshold: 0.6000000238418579
#        max_detections_per_class: 100
#        max_total_detections: 100
#        use_static_shapes: false
#      }
#      score_converter: SIGMOID
#    }
#    normalize_loss_by_num_matches: true
#    loss {
#      localization_loss {
#        weighted_smooth_l1 {
#        }
#      }
#      classification_loss {
#        weighted_sigmoid_focal {
#          gamma: 2.0
#          alpha: 0.25
#        }
#      }
#      classification_weight: 1.0
#      localization_weight: 1.0
#    }
#    encode_background_as_zeros: true
#    normalize_loc_loss_by_codesize: true
#    inplace_batchnorm_update: true
#    freeze_batchnorm: false
#  },
#  'train_config': batch_size: 128
#  data_augmentation_options {
#    random_horizontal_flip {
#    }
#  }
#  data_augmentation_options {
#    random_crop_image {
#      min_object_covered: 0.0
#      min_aspect_ratio: 0.75
#      max_aspect_ratio: 3.0
#      min_area: 0.75
#      max_area: 1.0
#      overlap_thresh: 0.0
#    }
#  }
#  sync_replicas: true
#  optimizer {
#    momentum_optimizer {
#      learning_rate {
#        cosine_decay_learning_rate {
#          learning_rate_base: 0.07999999821186066
#          total_steps: 50000
#          warmup_learning_rate: 0.026666000485420227
#          warmup_steps: 1000
#        }
#      }
#      momentum_optimizer_value: 0.8999999761581421
#    }
#    use_moving_average: false
#  }
#  fine_tune_checkpoint: "PATH_TO_BE_CONFIGURED"
#  num_steps: 50000
#  startup_delay_steps: 0.0
#  replicas_to_aggregate: 8
#  max_number_of_boxes: 100
#  unpad_groundtruth_tensors: false
#  fine_tune_checkpoint_type: "classification"
#  fine_tune_checkpoint_version: V2,
#  'train_input_config': label_map_path: "PATH_TO_BE_CONFIGURED"
#  tf_record_input_reader {
#    input_path: "PATH_TO_BE_CONFIGURED"
#  },
#  'eval_config': metrics_set: "coco_detection_metrics"
#  use_moving_averages: false,
#  'eval_input_configs': [label_map_path: "PATH_TO_BE_CONFIGURED"
#  shuffle: false
#  num_epochs: 1
#  tf_record_input_reader {
#    input_path: "PATH_TO_BE_CONFIGURED"
#  }
#  ],
#  'eval_input_config': label_map_path: "PATH_TO_BE_CONFIGURED"
#  shuffle: false
#  num_epochs: 1
#  tf_record_input_reader {
#    input_path: "PATH_TO_BE_CONFIGURED"
#  }}

# %%
pipeline_config = pipeline_pb2.TrainEvalPipelineConfig()
with tf.io.gfile.GFile(files['PIPELINE_CONFIG'], "r") as f:                                                                                                                                                                                                                     
    proto_str = f.read()                                                                                                                                                                                                                                          
    text_format.Merge(proto_str, pipeline_config)

# %%
pipeline_config.model.ssd.num_classes = len(labels)
pipeline_config.train_config.batch_size = 4
pipeline_config.train_config.fine_tune_checkpoint = os.path.join(paths['PRETRAINED_MODEL_PATH'], PRETRAINED_MODEL_NAME, 'checkpoint', 'ckpt-0')
pipeline_config.train_config.fine_tune_checkpoint_type = "detection"
pipeline_config.train_input_reader.label_map_path= files['LABELMAP']
pipeline_config.train_input_reader.tf_record_input_reader.input_path[:] = [os.path.join(paths['ANNOTATION_PATH'], 'train.record')]
pipeline_config.eval_input_reader[0].label_map_path = files['LABELMAP']
pipeline_config.eval_input_reader[0].tf_record_input_reader.input_path[:] = [os.path.join(paths['ANNOTATION_PATH'], 'test.record')]

# %%
config_text = text_format.MessageToString(pipeline_config)                                                                                                                                                                                                        
with tf.io.gfile.GFile(files['PIPELINE_CONFIG'], "wb") as f:                                                                                                                                                                                                                     
    f.write(config_text)

# %%
TRAINING_SCRIPT = os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection', 'model_main_tf2.py')

# %%
command = "python {} --model_dir={} --pipeline_config_path={} --num_train_steps=2000".format(TRAINING_SCRIPT, paths['CHECKPOINT_PATH'],files['PIPELINE_CONFIG'])

# %%
print(command)
# Out:
# python Tensorflow\models\research\object_detection\model_main_tf2.py --model_dir=Tensorflow\workspace\models\my_ssd_mobnet_finalsign --pipeline_config_path=Tensorflow\workspace\models\my_ssd_mobnet_finalsign\pipeline.config --num_train_steps=2000

# %%
# !pip install typeguard
# Out:
# Requirement already satisfied: typeguard in c:\programming\hackathon-2022\hackathon\lib\site-packages (2.13.3)

# %%
# !python Tensorflow\models\research\object_detection\model_main_tf2.py --model_dir=Tensorflow\workspace\models\my_ssd_mobnet_finalsign --pipeline_config_path=Tensorflow\workspace\models\my_ssd_mobnet_finalsign\pipeline.config --num_train_steps=25000
# Out:
# 2022-05-12 20:35:03.174429: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX AVX2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-05-12 20:35:03.689731: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2147 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1650 Ti, pci bus id: 0000:01:00.0, compute capability: 7.5
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# I0512 20:35:03.697958 23156 mirrored_strategy.py:376] Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# INFO:tensorflow:Maybe overwriting train_steps: 25000
# I0512 20:35:03.700959 23156 config_util.py:552] Maybe overwriting train_steps: 25000
# INFO:tensorflow:Maybe overwriting use_bfloat16: False
# I0512 20:35:03.701961 23156 config_util.py:552] Maybe overwriting use_bfloat16: False
# WARNING:tensorflow:From C:\Programming\Hackathon-2022\hackathon\lib\site-packages\object_detection-0.1-py3.8.egg\object_detection\model_lib_v2.py:563: StrategyBase.experimental_distribute_datasets_from_function (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# rename to distribute_datasets_from_function
# W0512 20:35:04.165072 23156 deprecation.py:341] From C:\Programming\Hackathon-2022\hackathon\lib\site-packages\object_detection-0.1-py3.8.egg\object_detection\model_lib_v2.py:563: StrategyBase.experimental_distribute_datasets_from_function (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# rename to distribute_datasets_from_function
# INFO:tensorflow:Reading unweighted datasets: ['Tensorflow\\workspace\\annotations\\train.record']
# I0512 20:35:04.170065 23156 dataset_builder.py:163] Reading unweighted datasets: ['Tensorflow\\workspace\\annotations\\train.record']
# INFO:tensorflow:Reading record datasets for input file: ['Tensorflow\\workspace\\annotations\\train.record']
# I0512 20:35:04.170065 23156 dataset_builder.py:80] Reading record datasets for input file: ['Tensorflow\\workspace\\annotations\\train.record']
# INFO:tensorflow:Number of filenames to read: 1
# I0512 20:35:04.170065 23156 dataset_builder.py:81] Number of filenames to read: 1
# WARNING:tensorflow:num_readers has been reduced to 1 to match input file shards.
# W0512 20:35:04.170065 23156 dataset_builder.py:87] num_readers has been reduced to 1 to match input file shards.
# WARNING:tensorflow:From C:\Programming\Hackathon-2022\hackathon\lib\site-packages\object_detection-0.1-py3.8.egg\object_detection\builders\dataset_builder.py:101: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# W0512 20:35:04.173066 23156 deprecation.py:341] From C:\Programming\Hackathon-2022\hackathon\lib\site-packages\object_detection-0.1-py3.8.egg\object_detection\builders\dataset_builder.py:101: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# WARNING:tensorflow:From C:\Programming\Hackathon-2022\hackathon\lib\site-packages\object_detection-0.1-py3.8.egg\object_detection\builders\dataset_builder.py:236: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# W0512 20:35:04.192090 23156 deprecation.py:341] From C:\Programming\Hackathon-2022\hackathon\lib\site-packages\object_detection-0.1-py3.8.egg\object_detection\builders\dataset_builder.py:236: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# WARNING:tensorflow:From C:\Programming\Hackathon-2022\hackathon\lib\site-packages\tensorflow\python\util\dispatch.py:1096: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# W0512 20:35:09.067242 23156 deprecation.py:341] From C:\Programming\Hackathon-2022\hackathon\lib\site-packages\tensorflow\python\util\dispatch.py:1096: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# WARNING:tensorflow:From C:\Programming\Hackathon-2022\hackathon\lib\site-packages\tensorflow\python\util\dispatch.py:1096: sample_distorted_bounding_box (from tensorflow.python.ops.image_ops_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# `seed2` arg is deprecated.Use sample_distorted_bounding_box_v2 instead.
# W0512 20:35:11.145695 23156 deprecation.py:341] From C:\Programming\Hackathon-2022\hackathon\lib\site-packages\tensorflow\python\util\dispatch.py:1096: sample_distorted_bounding_box (from tensorflow.python.ops.image_ops_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# `seed2` arg is deprecated.Use sample_distorted_bounding_box_v2 instead.
# WARNING:tensorflow:From C:\Programming\Hackathon-2022\hackathon\lib\site-packages\tensorflow\python\autograph\impl\api.py:465: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W0512 20:35:12.421996 23156 deprecation.py:341] From C:\Programming\Hackathon-2022\hackathon\lib\site-packages\tensorflow\python\autograph\impl\api.py:465: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# 2022-05-12 20:35:48.481930: I tensorflow/stream_executor/cuda/cuda_dnn.cc:366] Loaded cuDNN version 8100
# C:\Programming\Hackathon-2022\hackathon\lib\site-packages\keras\backend.py:414: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn('`tf.keras.backend.set_learning_phase` is deprecated and '
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0512 20:35:52.518733 23156 cross_device_ops.py:619] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0512 20:35:52.519724 23156 cross_device_ops.py:619] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0512 20:35:52.521729 23156 cross_device_ops.py:619] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0512 20:35:52.522729 23156 cross_device_ops.py:619] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0512 20:35:52.523734 23156 cross_device_ops.py:619] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0512 20:35:52.524746 23156 cross_device_ops.py:619] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0512 20:35:52.526727 23156 cross_device_ops.py:619] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0512 20:35:52.527730 23156 cross_device_ops.py:619] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0512 20:35:52.528747 23156 cross_device_ops.py:619] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0512 20:35:52.529747 23156 cross_device_ops.py:619] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# WARNING:tensorflow:From C:\Programming\Hackathon-2022\hackathon\lib\site-packages\tensorflow\python\util\deprecation.py:620: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead
# W0512 20:35:53.021143 11624 deprecation.py:545] From C:\Programming\Hackathon-2022\hackathon\lib\site-packages\tensorflow\python\util\deprecation.py:620: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead
# INFO:tensorflow:Step 100 per-step time 0.687s
# I0512 20:37:01.602233 23156 model_lib_v2.py:705] Step 100 per-step time 0.687s
# INFO:tensorflow:{'Loss/classification_loss': 0.5207715,
#  'Loss/localization_loss': 0.43413544,
#  'Loss/regularization_loss': 0.15434587,
#  'Loss/total_loss': 1.1092528,
#  'learning_rate': 0.0319994}
# I0512 20:37:01.624236 23156 model_lib_v2.py:708] {'Loss/classification_loss': 0.5207715,
#  'Loss/localization_loss': 0.43413544,
#  'Loss/regularization_loss': 0.15434587,
#  'Loss/total_loss': 1.1092528,
#  'learning_rate': 0.0319994}
# INFO:tensorflow:Step 200 per-step time 0.324s
# I0512 20:37:33.853541 23156 model_lib_v2.py:705] Step 200 per-step time 0.324s
# INFO:tensorflow:{'Loss/classification_loss': 0.40796667,
#  'Loss/localization_loss': 0.3183193,
#  'Loss/regularization_loss': 0.1547687,
#  'Loss/total_loss': 0.88105464,
#  'learning_rate': 0.0373328}
# I0512 20:37:33.854542 23156 model_lib_v2.py:708] {'Loss/classification_loss': 0.40796667,
#  'Loss/localization_loss': 0.3183193,
#  'Loss/regularization_loss': 0.1547687,
#  'Loss/total_loss': 0.88105464,
#  'learning_rate': 0.0373328}
# INFO:tensorflow:Step 300 per-step time 0.333s
# I0512 20:38:07.218101 23156 model_lib_v2.py:705] Step 300 per-step time 0.333s
# INFO:tensorflow:{'Loss/classification_loss': 0.5284756,
#  'Loss/localization_loss': 0.33453125,
#  'Loss/regularization_loss': 0.15493679,
#  'Loss/total_loss': 1.0179436,
#  'learning_rate': 0.0426662}
# I0512 20:38:07.220103 23156 model_lib_v2.py:708] {'Loss/classification_loss': 0.5284756,
#  'Loss/localization_loss': 0.33453125,
#  'Loss/regularization_loss': 0.15493679,
#  'Loss/total_loss': 1.0179436,
#  'learning_rate': 0.0426662}
# INFO:tensorflow:Step 400 per-step time 0.337s
# I0512 20:38:40.876738 23156 model_lib_v2.py:705] Step 400 per-step time 0.337s
# INFO:tensorflow:{'Loss/classification_loss': 0.5368917,
#  'Loss/localization_loss': 0.36782804,
#  'Loss/regularization_loss': 0.15497038,
#  'Loss/total_loss': 1.0596901,
#  'learning_rate': 0.047999598}
# I0512 20:38:40.877737 23156 model_lib_v2.py:708] {'Loss/classification_loss': 0.5368917,
#  'Loss/localization_loss': 0.36782804,
#  'Loss/regularization_loss': 0.15497038,
#  'Loss/total_loss': 1.0596901,
#  'learning_rate': 0.047999598}
# INFO:tensorflow:Step 500 per-step time 0.319s
# I0512 20:39:12.828980 23156 model_lib_v2.py:705] Step 500 per-step time 0.319s
# INFO:tensorflow:{'Loss/classification_loss': 0.3843686,
#  'Loss/localization_loss': 0.32579583,
#  'Loss/regularization_loss': 0.15513827,
#  'Loss/total_loss': 0.8653027,
#  'learning_rate': 0.053333}
# I0512 20:39:12.830978 23156 model_lib_v2.py:708] {'Loss/classification_loss': 0.3843686,
#  'Loss/localization_loss': 0.32579583,
#  'Loss/regularization_loss': 0.15513827,
#  'Loss/total_loss': 0.8653027,
#  'learning_rate': 0.053333}
# INFO:tensorflow:Step 600 per-step time 0.341s
# I0512 20:39:46.882693 23156 model_lib_v2.py:705] Step 600 per-step time 0.341s
# INFO:tensorflow:{'Loss/classification_loss': 0.5304324,
#  'Loss/localization_loss': 0.40376973,
#  'Loss/regularization_loss': 0.15534808,
#  'Loss/total_loss': 1.0895503,
#  'learning_rate': 0.0586664}
# I0512 20:39:46.882693 23156 model_lib_v2.py:708] {'Loss/classification_loss': 0.5304324,
#  'Loss/localization_loss': 0.40376973,
#  'Loss/regularization_loss': 0.15534808,
#  'Loss/total_loss': 1.0895503,
#  'learning_rate': 0.0586664}
# INFO:tensorflow:Step 700 per-step time 0.314s
# I0512 20:40:18.234797 23156 model_lib_v2.py:705] Step 700 per-step time 0.314s
# INFO:tensorflow:{'Loss/classification_loss': 0.40761298,
#  'Loss/localization_loss': 0.14403066,
#  'Loss/regularization_loss': 0.15567231,
#  'Loss/total_loss': 0.7073159,
#  'learning_rate': 0.0639998}
# I0512 20:40:18.235797 23156 model_lib_v2.py:708] {'Loss/classification_loss': 0.40761298,
#  'Loss/localization_loss': 0.14403066,
#  'Loss/regularization_loss': 0.15567231,
#  'Loss/total_loss': 0.7073159,
#  'learning_rate': 0.0639998}
# INFO:tensorflow:Step 800 per-step time 0.312s
# I0512 20:40:49.467464 23156 model_lib_v2.py:705] Step 800 per-step time 0.312s
# INFO:tensorflow:{'Loss/classification_loss': 0.38381213,
#  'Loss/localization_loss': 0.2114755,
#  'Loss/regularization_loss': 0.15583238,
#  'Loss/total_loss': 0.75112,
#  'learning_rate': 0.069333196}
# I0512 20:40:49.467464 23156 model_lib_v2.py:708] {'Loss/classification_loss': 0.38381213,
#  'Loss/localization_loss': 0.2114755,
#  'Loss/regularization_loss': 0.15583238,
#  'Loss/total_loss': 0.75112,
#  'learning_rate': 0.069333196}
# INFO:tensorflow:Step 900 per-step time 0.317s
# I0512 20:41:21.185656 23156 model_lib_v2.py:705] Step 900 per-step time 0.317s
# INFO:tensorflow:{'Loss/classification_loss': 0.33337742,
#  'Loss/localization_loss': 0.24488968,
#  'Loss/regularization_loss': 0.15604673,
#  'Loss/total_loss': 0.73431385,
#  'learning_rate': 0.074666604}
# I0512 20:41:21.186654 23156 model_lib_v2.py:708] {'Loss/classification_loss': 0.33337742,
#  'Loss/localization_loss': 0.24488968,
#  'Loss/regularization_loss': 0.15604673,
#  'Loss/total_loss': 0.73431385,
#  'learning_rate': 0.074666604}
# INFO:tensorflow:Step 1000 per-step time 0.324s
# I0512 20:41:53.646574 23156 model_lib_v2.py:705] Step 1000 per-step time 0.324s
# INFO:tensorflow:{'Loss/classification_loss': 0.36691827,
#  'Loss/localization_loss': 0.21366382,
#  'Loss/regularization_loss': 0.15640043,
#  'Loss/total_loss': 0.7369825,
#  'learning_rate': 0.08}
# I0512 20:41:53.648573 23156 model_lib_v2.py:708] {'Loss/classification_loss': 0.36691827,
#  'Loss/localization_loss': 0.21366382,
#  'Loss/regularization_loss': 0.15640043,
#  'Loss/total_loss': 0.7369825,
#  'learning_rate': 0.08}
# INFO:tensorflow:Step 1100 per-step time 0.326s
# I0512 20:42:26.190828 23156 model_lib_v2.py:705] Step 1100 per-step time 0.326s
# INFO:tensorflow:{'Loss/classification_loss': 0.37833416,
#  'Loss/localization_loss': 0.32063025,
#  'Loss/regularization_loss': 0.1571287,
#  'Loss/total_loss': 0.8560931,
#  'learning_rate': 0.07999918}
# I0512 20:42:26.190828 23156 model_lib_v2.py:708] {'Loss/classification_loss': 0.37833416,
#  'Loss/localization_loss': 0.32063025,
#  'Loss/regularization_loss': 0.1571287,
#  'Loss/total_loss': 0.8560931,
#  'learning_rate': 0.07999918}
# INFO:tensorflow:Step 1200 per-step time 0.322s
# I0512 20:42:58.375422 23156 model_lib_v2.py:705] Step 1200 per-step time 0.322s
# INFO:tensorflow:{'Loss/classification_loss': 0.33215365,
#  'Loss/localization_loss': 0.25433153,
#  'Loss/regularization_loss': 0.1576585,
#  'Loss/total_loss': 0.74414366,
#  'learning_rate': 0.079996705}
# I0512 20:42:58.376421 23156 model_lib_v2.py:708] {'Loss/classification_loss': 0.33215365,
#  'Loss/localization_loss': 0.25433153,
#  'Loss/regularization_loss': 0.1576585,
#  'Loss/total_loss': 0.74414366,
#  'learning_rate': 0.079996705}
# INFO:tensorflow:Step 1300 per-step time 0.320s
# I0512 20:43:30.397908 23156 model_lib_v2.py:705] Step 1300 per-step time 0.320s
# INFO:tensorflow:{'Loss/classification_loss': 0.24240075,
#  'Loss/localization_loss': 0.14241241,
#  'Loss/regularization_loss': 0.15779766,
#  'Loss/total_loss': 0.5426108,
#  'learning_rate': 0.0799926}
# I0512 20:43:30.398904 23156 model_lib_v2.py:708] {'Loss/classification_loss': 0.24240075,
#  'Loss/localization_loss': 0.14241241,
#  'Loss/regularization_loss': 0.15779766,
#  'Loss/total_loss': 0.5426108,
#  'learning_rate': 0.0799926}
# INFO:tensorflow:Step 1400 per-step time 0.308s
# I0512 20:44:01.248911 23156 model_lib_v2.py:705] Step 1400 per-step time 0.308s
# INFO:tensorflow:{'Loss/classification_loss': 0.20805155,
#  'Loss/localization_loss': 0.19107875,
#  'Loss/regularization_loss': 0.15764543,
#  'Loss/total_loss': 0.5567757,
#  'learning_rate': 0.07998685}
# I0512 20:44:01.249895 23156 model_lib_v2.py:708] {'Loss/classification_loss': 0.20805155,
#  'Loss/localization_loss': 0.19107875,
#  'Loss/regularization_loss': 0.15764543,
#  'Loss/total_loss': 0.5567757,
#  'learning_rate': 0.07998685}
# INFO:tensorflow:Step 1500 per-step time 0.338s
# I0512 20:44:35.009548 23156 model_lib_v2.py:705] Step 1500 per-step time 0.338s
# INFO:tensorflow:{'Loss/classification_loss': 0.24793345,
#  'Loss/localization_loss': 0.20031656,
#  'Loss/regularization_loss': 0.15758744,
#  'Loss/total_loss': 0.60583746,
#  'learning_rate': 0.07997945}
# I0512 20:44:35.010557 23156 model_lib_v2.py:708] {'Loss/classification_loss': 0.24793345,
#  'Loss/localization_loss': 0.20031656,
#  'Loss/regularization_loss': 0.15758744,
#  'Loss/total_loss': 0.60583746,
#  'learning_rate': 0.07997945}
# INFO:tensorflow:Step 1600 per-step time 0.323s
# I0512 20:45:07.312825 23156 model_lib_v2.py:705] Step 1600 per-step time 0.323s
# INFO:tensorflow:{'Loss/classification_loss': 0.23757227,
#  'Loss/localization_loss': 0.18358205,
#  'Loss/regularization_loss': 0.15759523,
#  'Loss/total_loss': 0.57874954,
#  'learning_rate': 0.079970405}
# I0512 20:45:07.313827 23156 model_lib_v2.py:708] {'Loss/classification_loss': 0.23757227,
#  'Loss/localization_loss': 0.18358205,
#  'Loss/regularization_loss': 0.15759523,
#  'Loss/total_loss': 0.57874954,
#  'learning_rate': 0.079970405}
# INFO:tensorflow:Step 1700 per-step time 0.327s
# I0512 20:45:40.147288 23156 model_lib_v2.py:705] Step 1700 per-step time 0.327s
# INFO:tensorflow:{'Loss/classification_loss': 0.27190405,
#  'Loss/localization_loss': 0.2007934,
#  'Loss/regularization_loss': 0.15745784,
#  'Loss/total_loss': 0.63015527,
#  'learning_rate': 0.07995972}
# I0512 20:45:40.149278 23156 model_lib_v2.py:708] {'Loss/classification_loss': 0.27190405,
#  'Loss/localization_loss': 0.2007934,
#  'Loss/regularization_loss': 0.15745784,
#  'Loss/total_loss': 0.63015527,
#  'learning_rate': 0.07995972}
# INFO:tensorflow:Step 1800 per-step time 0.338s
# I0512 20:46:13.815898 23156 model_lib_v2.py:705] Step 1800 per-step time 0.338s
# INFO:tensorflow:{'Loss/classification_loss': 0.24548931,
#  'Loss/localization_loss': 0.13715054,
#  'Loss/regularization_loss': 0.15739638,
#  'Loss/total_loss': 0.5400362,
#  'learning_rate': 0.0799474}
# I0512 20:46:13.815898 23156 model_lib_v2.py:708] {'Loss/classification_loss': 0.24548931,
#  'Loss/localization_loss': 0.13715054,
#  'Loss/regularization_loss': 0.15739638,
#  'Loss/total_loss': 0.5400362,
#  'learning_rate': 0.0799474}
# INFO:tensorflow:Step 1900 per-step time 0.348s
# I0512 20:46:48.643795 23156 model_lib_v2.py:705] Step 1900 per-step time 0.348s
# INFO:tensorflow:{'Loss/classification_loss': 0.20240952,
#  'Loss/localization_loss': 0.15191276,
#  'Loss/regularization_loss': 0.15719794,
#  'Loss/total_loss': 0.5115202,
#  'learning_rate': 0.07993342}
# I0512 20:46:48.644792 23156 model_lib_v2.py:708] {'Loss/classification_loss': 0.20240952,
#  'Loss/localization_loss': 0.15191276,
#  'Loss/regularization_loss': 0.15719794,
#  'Loss/total_loss': 0.5115202,
#  'learning_rate': 0.07993342}
# INFO:tensorflow:Step 2000 per-step time 0.331s
# I0512 20:47:21.730288 23156 model_lib_v2.py:705] Step 2000 per-step time 0.331s
# INFO:tensorflow:{'Loss/classification_loss': 0.2541704,
#  'Loss/localization_loss': 0.17839848,
#  'Loss/regularization_loss': 0.15706545,
#  'Loss/total_loss': 0.5896343,
#  'learning_rate': 0.07991781}
# I0512 20:47:21.730288 23156 model_lib_v2.py:708] {'Loss/classification_loss': 0.2541704,
#  'Loss/localization_loss': 0.17839848,
#  'Loss/regularization_loss': 0.15706545,
#  'Loss/total_loss': 0.5896343,
#  'learning_rate': 0.07991781}
# INFO:tensorflow:Step 2100 per-step time 0.316s
# I0512 20:47:53.342450 23156 model_lib_v2.py:705] Step 2100 per-step time 0.316s
# INFO:tensorflow:{'Loss/classification_loss': 0.24078196,
#  'Loss/localization_loss': 0.11812682,
#  'Loss/regularization_loss': 0.156827,
#  'Loss/total_loss': 0.51573575,
#  'learning_rate': 0.07990056}
# I0512 20:47:53.343455 23156 model_lib_v2.py:708] {'Loss/classification_loss': 0.24078196,
#  'Loss/localization_loss': 0.11812682,
#  'Loss/regularization_loss': 0.156827,
#  'Loss/total_loss': 0.51573575,
#  'learning_rate': 0.07990056}
# INFO:tensorflow:Step 2200 per-step time 0.325s
# I0512 20:48:25.850821 23156 model_lib_v2.py:705] Step 2200 per-step time 0.325s
# INFO:tensorflow:{'Loss/classification_loss': 0.3028951,
#  'Loss/localization_loss': 0.2978104,
#  'Loss/regularization_loss': 0.15669404,
#  'Loss/total_loss': 0.75739956,
#  'learning_rate': 0.07988167}
# I0512 20:48:25.851824 23156 model_lib_v2.py:708] {'Loss/classification_loss': 0.3028951,
#  'Loss/localization_loss': 0.2978104,
#  'Loss/regularization_loss': 0.15669404,
#  'Loss/total_loss': 0.75739956,
#  'learning_rate': 0.07988167}
# INFO:tensorflow:Step 2300 per-step time 0.338s
# I0512 20:48:59.767505 23156 model_lib_v2.py:705] Step 2300 per-step time 0.338s
# INFO:tensorflow:{'Loss/classification_loss': 0.23990525,
#  'Loss/localization_loss': 0.15689267,
#  'Loss/regularization_loss': 0.15633103,
#  'Loss/total_loss': 0.55312896,
#  'learning_rate': 0.07986114}
# I0512 20:48:59.769510 23156 model_lib_v2.py:708] {'Loss/classification_loss': 0.23990525,
#  'Loss/localization_loss': 0.15689267,
#  'Loss/regularization_loss': 0.15633103,
#  'Loss/total_loss': 0.55312896,
#  'learning_rate': 0.07986114}
# INFO:tensorflow:Step 2400 per-step time 0.354s
# I0512 20:49:35.043290 23156 model_lib_v2.py:705] Step 2400 per-step time 0.354s
# INFO:tensorflow:{'Loss/classification_loss': 0.22709209,
#  'Loss/localization_loss': 0.23617056,
#  'Loss/regularization_loss': 0.1560548,
#  'Loss/total_loss': 0.6193174,
#  'learning_rate': 0.07983897}
# I0512 20:49:35.044289 23156 model_lib_v2.py:708] {'Loss/classification_loss': 0.22709209,
#  'Loss/localization_loss': 0.23617056,
#  'Loss/regularization_loss': 0.1560548,
#  'Loss/total_loss': 0.6193174,
#  'learning_rate': 0.07983897}
# INFO:tensorflow:Step 2500 per-step time 0.329s
# I0512 20:50:08.009766 23156 model_lib_v2.py:705] Step 2500 per-step time 0.329s
# INFO:tensorflow:{'Loss/classification_loss': 0.13453622,
#  'Loss/localization_loss': 0.062597,
#  'Loss/regularization_loss': 0.15562108,
#  'Loss/total_loss': 0.3527543,
#  'learning_rate': 0.079815164}
# I0512 20:50:08.010775 23156 model_lib_v2.py:708] {'Loss/classification_loss': 0.13453622,
#  'Loss/localization_loss': 0.062597,
#  'Loss/regularization_loss': 0.15562108,
#  'Loss/total_loss': 0.3527543,
#  'learning_rate': 0.079815164}
# INFO:tensorflow:Step 2600 per-step time 0.333s
# I0512 20:50:41.273302 23156 model_lib_v2.py:705] Step 2600 per-step time 0.333s
# INFO:tensorflow:{'Loss/classification_loss': 0.18955661,
#  'Loss/localization_loss': 0.11923393,
#  'Loss/regularization_loss': 0.1552222,
#  'Loss/total_loss': 0.46401274,
#  'learning_rate': 0.07978972}
# I0512 20:50:41.274305 23156 model_lib_v2.py:708] {'Loss/classification_loss': 0.18955661,
#  'Loss/localization_loss': 0.11923393,
#  'Loss/regularization_loss': 0.1552222,
#  'Loss/total_loss': 0.46401274,
#  'learning_rate': 0.07978972}
# INFO:tensorflow:Step 2700 per-step time 0.318s
# I0512 20:51:13.088681 23156 model_lib_v2.py:705] Step 2700 per-step time 0.318s
# INFO:tensorflow:{'Loss/classification_loss': 0.20380537,
#  'Loss/localization_loss': 0.11127579,
#  'Loss/regularization_loss': 0.15497701,
#  'Loss/total_loss': 0.4700582,
#  'learning_rate': 0.07976264}
# I0512 20:51:13.089684 23156 model_lib_v2.py:708] {'Loss/classification_loss': 0.20380537,
#  'Loss/localization_loss': 0.11127579,
#  'Loss/regularization_loss': 0.15497701,
#  'Loss/total_loss': 0.4700582,
#  'learning_rate': 0.07976264}
# INFO:tensorflow:Step 2800 per-step time 0.298s
# I0512 20:51:42.909443 23156 model_lib_v2.py:705] Step 2800 per-step time 0.298s
# INFO:tensorflow:{'Loss/classification_loss': 0.20000568,
#  'Loss/localization_loss': 0.104773045,
#  'Loss/regularization_loss': 0.15465474,
#  'Loss/total_loss': 0.45943347,
#  'learning_rate': 0.07973392}
# I0512 20:51:42.910441 23156 model_lib_v2.py:708] {'Loss/classification_loss': 0.20000568,
#  'Loss/localization_loss': 0.104773045,
#  'Loss/regularization_loss': 0.15465474,
#  'Loss/total_loss': 0.45943347,
#  'learning_rate': 0.07973392}
# INFO:tensorflow:Step 2900 per-step time 0.316s
# I0512 20:52:14.536607 23156 model_lib_v2.py:705] Step 2900 per-step time 0.316s
# INFO:tensorflow:{'Loss/classification_loss': 0.17193699,
#  'Loss/localization_loss': 0.060493868,
#  'Loss/regularization_loss': 0.1543937,
#  'Loss/total_loss': 0.38682455,
#  'learning_rate': 0.07970358}
# I0512 20:52:14.538614 23156 model_lib_v2.py:708] {'Loss/classification_loss': 0.17193699,
#  'Loss/localization_loss': 0.060493868,
#  'Loss/regularization_loss': 0.1543937,
#  'Loss/total_loss': 0.38682455,
#  'learning_rate': 0.07970358}
# INFO:tensorflow:Step 3000 per-step time 0.333s
# I0512 20:52:47.901869 23156 model_lib_v2.py:705] Step 3000 per-step time 0.333s
# INFO:tensorflow:{'Loss/classification_loss': 0.115918525,
#  'Loss/localization_loss': 0.09641823,
#  'Loss/regularization_loss': 0.15401392,
#  'Loss/total_loss': 0.36635065,
#  'learning_rate': 0.0796716}
# I0512 20:52:47.902868 23156 model_lib_v2.py:708] {'Loss/classification_loss': 0.115918525,
#  'Loss/localization_loss': 0.09641823,
#  'Loss/regularization_loss': 0.15401392,
#  'Loss/total_loss': 0.36635065,
#  'learning_rate': 0.0796716}
# INFO:tensorflow:Step 3100 per-step time 0.337s
# I0512 20:53:21.584261 23156 model_lib_v2.py:705] Step 3100 per-step time 0.337s
# INFO:tensorflow:{'Loss/classification_loss': 0.16137232,
#  'Loss/localization_loss': 0.06497949,
#  'Loss/regularization_loss': 0.15361726,
#  'Loss/total_loss': 0.37996906,
#  'learning_rate': 0.07963799}
# I0512 20:53:21.585255 23156 model_lib_v2.py:708] {'Loss/classification_loss': 0.16137232,
#  'Loss/localization_loss': 0.06497949,
#  'Loss/regularization_loss': 0.15361726,
#  'Loss/total_loss': 0.37996906,
#  'learning_rate': 0.07963799}
# INFO:tensorflow:Step 3200 per-step time 0.332s
# I0512 20:53:54.801364 23156 model_lib_v2.py:705] Step 3200 per-step time 0.332s
# INFO:tensorflow:{'Loss/classification_loss': 0.14357544,
#  'Loss/localization_loss': 0.061579477,
#  'Loss/regularization_loss': 0.15355119,
#  'Loss/total_loss': 0.35870612,
#  'learning_rate': 0.07960275}
# I0512 20:53:54.802361 23156 model_lib_v2.py:708] {'Loss/classification_loss': 0.14357544,
#  'Loss/localization_loss': 0.061579477,
#  'Loss/regularization_loss': 0.15355119,
#  'Loss/total_loss': 0.35870612,
#  'learning_rate': 0.07960275}
# INFO:tensorflow:Step 3300 per-step time 0.319s
# I0512 20:54:26.701586 23156 model_lib_v2.py:705] Step 3300 per-step time 0.319s
# INFO:tensorflow:{'Loss/classification_loss': 0.16561984,
#  'Loss/localization_loss': 0.22097732,
#  'Loss/regularization_loss': 0.15335432,
#  'Loss/total_loss': 0.53995144,
#  'learning_rate': 0.07956588}
# I0512 20:54:26.701586 23156 model_lib_v2.py:708] {'Loss/classification_loss': 0.16561984,
#  'Loss/localization_loss': 0.22097732,
#  'Loss/regularization_loss': 0.15335432,
#  'Loss/total_loss': 0.53995144,
#  'learning_rate': 0.07956588}
# INFO:tensorflow:Step 3400 per-step time 0.328s
# I0512 20:54:59.528568 23156 model_lib_v2.py:705] Step 3400 per-step time 0.328s
# INFO:tensorflow:{'Loss/classification_loss': 0.20687553,
#  'Loss/localization_loss': 0.07078369,
#  'Loss/regularization_loss': 0.15291263,
#  'Loss/total_loss': 0.43057185,
#  'learning_rate': 0.079527386}
# I0512 20:54:59.529568 23156 model_lib_v2.py:708] {'Loss/classification_loss': 0.20687553,
#  'Loss/localization_loss': 0.07078369,
#  'Loss/regularization_loss': 0.15291263,
#  'Loss/total_loss': 0.43057185,
#  'learning_rate': 0.079527386}
# INFO:tensorflow:Step 3500 per-step time 0.306s
# I0512 20:55:30.185320 23156 model_lib_v2.py:705] Step 3500 per-step time 0.306s
# INFO:tensorflow:{'Loss/classification_loss': 0.122985385,
#  'Loss/localization_loss': 0.05463482,
#  'Loss/regularization_loss': 0.15252776,
#  'Loss/total_loss': 0.33014798,
#  'learning_rate': 0.07948727}
# I0512 20:55:30.186319 23156 model_lib_v2.py:708] {'Loss/classification_loss': 0.122985385,
#  'Loss/localization_loss': 0.05463482,
#  'Loss/regularization_loss': 0.15252776,
#  'Loss/total_loss': 0.33014798,
#  'learning_rate': 0.07948727}
# INFO:tensorflow:Step 3600 per-step time 0.322s
# I0512 20:56:02.368008 23156 model_lib_v2.py:705] Step 3600 per-step time 0.322s
# INFO:tensorflow:{'Loss/classification_loss': 0.10499449,
#  'Loss/localization_loss': 0.09158571,
#  'Loss/regularization_loss': 0.15222418,
#  'Loss/total_loss': 0.34880438,
#  'learning_rate': 0.079445526}
# I0512 20:56:02.369009 23156 model_lib_v2.py:708] {'Loss/classification_loss': 0.10499449,
#  'Loss/localization_loss': 0.09158571,
#  'Loss/regularization_loss': 0.15222418,
#  'Loss/total_loss': 0.34880438,
#  'learning_rate': 0.079445526}
# INFO:tensorflow:Step 3700 per-step time 0.319s
# I0512 20:56:34.319590 23156 model_lib_v2.py:705] Step 3700 per-step time 0.319s
# INFO:tensorflow:{'Loss/classification_loss': 0.09207205,
#  'Loss/localization_loss': 0.07506888,
#  'Loss/regularization_loss': 0.15177901,
#  'Loss/total_loss': 0.31891996,
#  'learning_rate': 0.07940216}
# I0512 20:56:34.320589 23156 model_lib_v2.py:708] {'Loss/classification_loss': 0.09207205,
#  'Loss/localization_loss': 0.07506888,
#  'Loss/regularization_loss': 0.15177901,
#  'Loss/total_loss': 0.31891996,
#  'learning_rate': 0.07940216}
# INFO:tensorflow:Step 3800 per-step time 0.313s
# I0512 20:57:05.655625 23156 model_lib_v2.py:705] Step 3800 per-step time 0.313s
# INFO:tensorflow:{'Loss/classification_loss': 0.14640215,
#  'Loss/localization_loss': 0.080596656,
#  'Loss/regularization_loss': 0.15158772,
#  'Loss/total_loss': 0.37858653,
#  'learning_rate': 0.079357184}
# I0512 20:57:05.655625 23156 model_lib_v2.py:708] {'Loss/classification_loss': 0.14640215,
#  'Loss/localization_loss': 0.080596656,
#  'Loss/regularization_loss': 0.15158772,
#  'Loss/total_loss': 0.37858653,
#  'learning_rate': 0.079357184}
# INFO:tensorflow:Step 3900 per-step time 0.317s
# I0512 20:57:37.381318 23156 model_lib_v2.py:705] Step 3900 per-step time 0.317s
# INFO:tensorflow:{'Loss/classification_loss': 0.097213425,
#  'Loss/localization_loss': 0.062244963,
#  'Loss/regularization_loss': 0.15130302,
#  'Loss/total_loss': 0.3107614,
#  'learning_rate': 0.07931058}
# I0512 20:57:37.381318 23156 model_lib_v2.py:708] {'Loss/classification_loss': 0.097213425,
#  'Loss/localization_loss': 0.062244963,
#  'Loss/regularization_loss': 0.15130302,
#  'Loss/total_loss': 0.3107614,
#  'learning_rate': 0.07931058}
# INFO:tensorflow:Step 4000 per-step time 0.353s
# I0512 20:58:12.684067 23156 model_lib_v2.py:705] Step 4000 per-step time 0.353s
# INFO:tensorflow:{'Loss/classification_loss': 0.15194646,
#  'Loss/localization_loss': 0.08332012,
#  'Loss/regularization_loss': 0.15077186,
#  'Loss/total_loss': 0.38603842,
#  'learning_rate': 0.07926236}
# I0512 20:58:12.685067 23156 model_lib_v2.py:708] {'Loss/classification_loss': 0.15194646,
#  'Loss/localization_loss': 0.08332012,
#  'Loss/regularization_loss': 0.15077186,
#  'Loss/total_loss': 0.38603842,
#  'learning_rate': 0.07926236}
# INFO:tensorflow:Step 4100 per-step time 0.325s
# I0512 20:58:45.198434 23156 model_lib_v2.py:705] Step 4100 per-step time 0.325s
# INFO:tensorflow:{'Loss/classification_loss': 0.094211474,
#  'Loss/localization_loss': 0.08168392,
#  'Loss/regularization_loss': 0.15036955,
#  'Loss/total_loss': 0.32626495,
#  'learning_rate': 0.07921253}
# I0512 20:58:45.199439 23156 model_lib_v2.py:708] {'Loss/classification_loss': 0.094211474,
#  'Loss/localization_loss': 0.08168392,
#  'Loss/regularization_loss': 0.15036955,
#  'Loss/total_loss': 0.32626495,
#  'learning_rate': 0.07921253}
# INFO:tensorflow:Step 4200 per-step time 0.327s
# I0512 20:59:17.877844 23156 model_lib_v2.py:705] Step 4200 per-step time 0.327s
# INFO:tensorflow:{'Loss/classification_loss': 0.104032435,
#  'Loss/localization_loss': 0.056430217,
#  'Loss/regularization_loss': 0.1498585,
#  'Loss/total_loss': 0.31032115,
#  'learning_rate': 0.07916109}
# I0512 20:59:17.878844 23156 model_lib_v2.py:708] {'Loss/classification_loss': 0.104032435,
#  'Loss/localization_loss': 0.056430217,
#  'Loss/regularization_loss': 0.1498585,
#  'Loss/total_loss': 0.31032115,
#  'learning_rate': 0.07916109}
# INFO:tensorflow:Step 4300 per-step time 0.321s
# I0512 20:59:50.252183 23156 model_lib_v2.py:705] Step 4300 per-step time 0.321s
# INFO:tensorflow:{'Loss/classification_loss': 0.20493442,
#  'Loss/localization_loss': 0.118152484,
#  'Loss/regularization_loss': 0.14956298,
#  'Loss/total_loss': 0.4726499,
#  'learning_rate': 0.07910804}
# I0512 20:59:50.255181 23156 model_lib_v2.py:708] {'Loss/classification_loss': 0.20493442,
#  'Loss/localization_loss': 0.118152484,
#  'Loss/regularization_loss': 0.14956298,
#  'Loss/total_loss': 0.4726499,
#  'learning_rate': 0.07910804}
# INFO:tensorflow:Step 4400 per-step time 0.353s
# I0512 21:00:25.364137 23156 model_lib_v2.py:705] Step 4400 per-step time 0.353s
# INFO:tensorflow:{'Loss/classification_loss': 0.09954634,
#  'Loss/localization_loss': 0.05073566,
#  'Loss/regularization_loss': 0.14913096,
#  'Loss/total_loss': 0.29941297,
#  'learning_rate': 0.07905338}
# I0512 21:00:25.365142 23156 model_lib_v2.py:708] {'Loss/classification_loss': 0.09954634,
#  'Loss/localization_loss': 0.05073566,
#  'Loss/regularization_loss': 0.14913096,
#  'Loss/total_loss': 0.29941297,
#  'learning_rate': 0.07905338}
# INFO:tensorflow:Step 4500 per-step time 0.316s
# I0512 21:00:56.841277 23156 model_lib_v2.py:705] Step 4500 per-step time 0.316s
# INFO:tensorflow:{'Loss/classification_loss': 0.08667573,
#  'Loss/localization_loss': 0.03474762,
#  'Loss/regularization_loss': 0.1485137,
#  'Loss/total_loss': 0.26993704,
#  'learning_rate': 0.07899711}
# I0512 21:00:56.842278 23156 model_lib_v2.py:708] {'Loss/classification_loss': 0.08667573,
#  'Loss/localization_loss': 0.03474762,
#  'Loss/regularization_loss': 0.1485137,
#  'Loss/total_loss': 0.26993704,
#  'learning_rate': 0.07899711}
# INFO:tensorflow:Step 4600 per-step time 0.298s
# I0512 21:01:26.691038 23156 model_lib_v2.py:705] Step 4600 per-step time 0.298s
# INFO:tensorflow:{'Loss/classification_loss': 0.10358554,
#  'Loss/localization_loss': 0.057830617,
#  'Loss/regularization_loss': 0.1478989,
#  'Loss/total_loss': 0.30931506,
#  'learning_rate': 0.078939244}
# I0512 21:01:26.692036 23156 model_lib_v2.py:708] {'Loss/classification_loss': 0.10358554,
#  'Loss/localization_loss': 0.057830617,
#  'Loss/regularization_loss': 0.1478989,
#  'Loss/total_loss': 0.30931506,
#  'learning_rate': 0.078939244}
# INFO:tensorflow:Step 4700 per-step time 0.346s
# I0512 21:02:01.303885 23156 model_lib_v2.py:705] Step 4700 per-step time 0.346s
# INFO:tensorflow:{'Loss/classification_loss': 0.18753481,
#  'Loss/localization_loss': 0.12809671,
#  'Loss/regularization_loss': 0.1476462,
#  'Loss/total_loss': 0.4632777,
#  'learning_rate': 0.07887978}
# I0512 21:02:01.304883 23156 model_lib_v2.py:708] {'Loss/classification_loss': 0.18753481,
#  'Loss/localization_loss': 0.12809671,
#  'Loss/regularization_loss': 0.1476462,
#  'Loss/total_loss': 0.4632777,
#  'learning_rate': 0.07887978}
# INFO:tensorflow:Step 4800 per-step time 0.314s
# I0512 21:02:32.737018 23156 model_lib_v2.py:705] Step 4800 per-step time 0.314s
# INFO:tensorflow:{'Loss/classification_loss': 0.09522278,
#  'Loss/localization_loss': 0.04832751,
#  'Loss/regularization_loss': 0.14729671,
#  'Loss/total_loss': 0.290847,
#  'learning_rate': 0.07881871}
# I0512 21:02:32.738020 23156 model_lib_v2.py:708] {'Loss/classification_loss': 0.09522278,
#  'Loss/localization_loss': 0.04832751,
#  'Loss/regularization_loss': 0.14729671,
#  'Loss/total_loss': 0.290847,
#  'learning_rate': 0.07881871}
# INFO:tensorflow:Step 4900 per-step time 0.330s
# I0512 21:03:05.775492 23156 model_lib_v2.py:705] Step 4900 per-step time 0.330s
# INFO:tensorflow:{'Loss/classification_loss': 0.11126901,
#  'Loss/localization_loss': 0.04755469,
#  'Loss/regularization_loss': 0.14678034,
#  'Loss/total_loss': 0.30560404,
#  'learning_rate': 0.07875605}
# I0512 21:03:05.776499 23156 model_lib_v2.py:708] {'Loss/classification_loss': 0.11126901,
#  'Loss/localization_loss': 0.04755469,
#  'Loss/regularization_loss': 0.14678034,
#  'Loss/total_loss': 0.30560404,
#  'learning_rate': 0.07875605}
# INFO:tensorflow:Step 5000 per-step time 0.310s
# I0512 21:03:36.772519 23156 model_lib_v2.py:705] Step 5000 per-step time 0.310s
# INFO:tensorflow:{'Loss/classification_loss': 0.08371803,
#  'Loss/localization_loss': 0.07828883,
#  'Loss/regularization_loss': 0.1463862,
#  'Loss/total_loss': 0.30839306,
#  'learning_rate': 0.078691795}
# I0512 21:03:36.772519 23156 model_lib_v2.py:708] {'Loss/classification_loss': 0.08371803,
#  'Loss/localization_loss': 0.07828883,
#  'Loss/regularization_loss': 0.1463862,
#  'Loss/total_loss': 0.30839306,
#  'learning_rate': 0.078691795}
# INFO:tensorflow:Step 5100 per-step time 0.306s
# I0512 21:04:07.487487 23156 model_lib_v2.py:705] Step 5100 per-step time 0.306s
# INFO:tensorflow:{'Loss/classification_loss': 0.0905344,
#  'Loss/localization_loss': 0.045528118,
#  'Loss/regularization_loss': 0.14576395,
#  'Loss/total_loss': 0.28182647,
#  'learning_rate': 0.07862595}
# I0512 21:04:07.489493 23156 model_lib_v2.py:708] {'Loss/classification_loss': 0.0905344,
#  'Loss/localization_loss': 0.045528118,
#  'Loss/regularization_loss': 0.14576395,
#  'Loss/total_loss': 0.28182647,
#  'learning_rate': 0.07862595}
# INFO:tensorflow:Step 5200 per-step time 0.345s
# I0512 21:04:41.852269 23156 model_lib_v2.py:705] Step 5200 per-step time 0.345s
# INFO:tensorflow:{'Loss/classification_loss': 0.09571587,
#  'Loss/localization_loss': 0.085111804,
#  'Loss/regularization_loss': 0.14518595,
#  'Loss/total_loss': 0.32601362,
#  'learning_rate': 0.07855851}
# I0512 21:04:41.853271 23156 model_lib_v2.py:708] {'Loss/classification_loss': 0.09571587,
#  'Loss/localization_loss': 0.085111804,
#  'Loss/regularization_loss': 0.14518595,
#  'Loss/total_loss': 0.32601362,
#  'learning_rate': 0.07855851}
# INFO:tensorflow:Step 5300 per-step time 0.344s
# I0512 21:05:16.244063 23156 model_lib_v2.py:705] Step 5300 per-step time 0.344s
# INFO:tensorflow:{'Loss/classification_loss': 0.07979457,
#  'Loss/localization_loss': 0.030488444,
#  'Loss/regularization_loss': 0.14455736,
#  'Loss/total_loss': 0.25484037,
#  'learning_rate': 0.07848949}
# I0512 21:05:16.244063 23156 model_lib_v2.py:708] {'Loss/classification_loss': 0.07979457,
#  'Loss/localization_loss': 0.030488444,
#  'Loss/regularization_loss': 0.14455736,
#  'Loss/total_loss': 0.25484037,
#  'learning_rate': 0.07848949}
# INFO:tensorflow:Step 5400 per-step time 0.310s
# I0512 21:05:47.191081 23156 model_lib_v2.py:705] Step 5400 per-step time 0.310s
# INFO:tensorflow:{'Loss/classification_loss': 0.0820768,
#  'Loss/localization_loss': 0.044032615,
#  'Loss/regularization_loss': 0.1443438,
#  'Loss/total_loss': 0.2704532,
#  'learning_rate': 0.078418896}
# I0512 21:05:47.192083 23156 model_lib_v2.py:708] {'Loss/classification_loss': 0.0820768,
#  'Loss/localization_loss': 0.044032615,
#  'Loss/regularization_loss': 0.1443438,
#  'Loss/total_loss': 0.2704532,
#  'learning_rate': 0.078418896}
# INFO:tensorflow:Step 5500 per-step time 0.318s
# I0512 21:06:18.953777 23156 model_lib_v2.py:705] Step 5500 per-step time 0.318s
# INFO:tensorflow:{'Loss/classification_loss': 0.115184866,
#  'Loss/localization_loss': 0.04157998,
#  'Loss/regularization_loss': 0.14382298,
#  'Loss/total_loss': 0.30058783,
#  'learning_rate': 0.078346714}
# I0512 21:06:18.953777 23156 model_lib_v2.py:708] {'Loss/classification_loss': 0.115184866,
#  'Loss/localization_loss': 0.04157998,
#  'Loss/regularization_loss': 0.14382298,
#  'Loss/total_loss': 0.30058783,
#  'learning_rate': 0.078346714}
# INFO:tensorflow:Step 5600 per-step time 0.315s
# I0512 21:06:50.505863 23156 model_lib_v2.py:705] Step 5600 per-step time 0.315s
# INFO:tensorflow:{'Loss/classification_loss': 0.109023415,
#  'Loss/localization_loss': 0.052952245,
#  'Loss/regularization_loss': 0.1432918,
#  'Loss/total_loss': 0.30526745,
#  'learning_rate': 0.07827295}
# I0512 21:06:50.506855 23156 model_lib_v2.py:708] {'Loss/classification_loss': 0.109023415,
#  'Loss/localization_loss': 0.052952245,
#  'Loss/regularization_loss': 0.1432918,
#  'Loss/total_loss': 0.30526745,
#  'learning_rate': 0.07827295}
# INFO:tensorflow:Step 5700 per-step time 0.309s
# I0512 21:07:21.443413 23156 model_lib_v2.py:705] Step 5700 per-step time 0.309s
# INFO:tensorflow:{'Loss/classification_loss': 0.06790145,
#  'Loss/localization_loss': 0.027076807,
#  'Loss/regularization_loss': 0.14276129,
#  'Loss/total_loss': 0.23773955,
#  'learning_rate': 0.07819763}
# I0512 21:07:21.444410 23156 model_lib_v2.py:708] {'Loss/classification_loss': 0.06790145,
#  'Loss/localization_loss': 0.027076807,
#  'Loss/regularization_loss': 0.14276129,
#  'Loss/total_loss': 0.23773955,
#  'learning_rate': 0.07819763}
# INFO:tensorflow:Step 5800 per-step time 0.315s
# I0512 21:07:52.943550 23156 model_lib_v2.py:705] Step 5800 per-step time 0.315s
# INFO:tensorflow:{'Loss/classification_loss': 0.12551236,
#  'Loss/localization_loss': 0.08328506,
#  'Loss/regularization_loss': 0.14217304,
#  'Loss/total_loss': 0.35097045,
#  'learning_rate': 0.07812072}
# I0512 21:07:52.944547 23156 model_lib_v2.py:708] {'Loss/classification_loss': 0.12551236,
#  'Loss/localization_loss': 0.08328506,
#  'Loss/regularization_loss': 0.14217304,
#  'Loss/total_loss': 0.35097045,
#  'learning_rate': 0.07812072}
# INFO:tensorflow:Step 5900 per-step time 0.306s
# I0512 21:08:23.526478 23156 model_lib_v2.py:705] Step 5900 per-step time 0.306s
# INFO:tensorflow:{'Loss/classification_loss': 0.10992767,
#  'Loss/localization_loss': 0.079402745,
#  'Loss/regularization_loss': 0.14154953,
#  'Loss/total_loss': 0.33087993,
#  'learning_rate': 0.078042254}
# I0512 21:08:23.526478 23156 model_lib_v2.py:708] {'Loss/classification_loss': 0.10992767,
#  'Loss/localization_loss': 0.079402745,
#  'Loss/regularization_loss': 0.14154953,
#  'Loss/total_loss': 0.33087993,
#  'learning_rate': 0.078042254}
# INFO:tensorflow:Step 6000 per-step time 0.335s
# I0512 21:08:57.024072 23156 model_lib_v2.py:705] Step 6000 per-step time 0.335s
# INFO:tensorflow:{'Loss/classification_loss': 0.08964353,
#  'Loss/localization_loss': 0.04997269,
#  'Loss/regularization_loss': 0.14093748,
#  'Loss/total_loss': 0.2805537,
#  'learning_rate': 0.07796223}
# I0512 21:08:57.025074 23156 model_lib_v2.py:708] {'Loss/classification_loss': 0.08964353,
#  'Loss/localization_loss': 0.04997269,
#  'Loss/regularization_loss': 0.14093748,
#  'Loss/total_loss': 0.2805537,
#  'learning_rate': 0.07796223}
# INFO:tensorflow:Step 6100 per-step time 0.329s
# I0512 21:09:29.877623 23156 model_lib_v2.py:705] Step 6100 per-step time 0.329s
# INFO:tensorflow:{'Loss/classification_loss': 0.19420004,
#  'Loss/localization_loss': 0.08305331,
#  'Loss/regularization_loss': 0.14038022,
#  'Loss/total_loss': 0.4176336,
#  'learning_rate': 0.077880636}
# I0512 21:09:29.878623 23156 model_lib_v2.py:708] {'Loss/classification_loss': 0.19420004,
#  'Loss/localization_loss': 0.08305331,
#  'Loss/regularization_loss': 0.14038022,
#  'Loss/total_loss': 0.4176336,
#  'learning_rate': 0.077880636}
# INFO:tensorflow:Step 6200 per-step time 0.344s
# I0512 21:10:04.240422 23156 model_lib_v2.py:705] Step 6200 per-step time 0.344s
# INFO:tensorflow:{'Loss/classification_loss': 0.10819013,
#  'Loss/localization_loss': 0.033523697,
#  'Loss/regularization_loss': 0.14001691,
#  'Loss/total_loss': 0.28173074,
#  'learning_rate': 0.07779749}
# I0512 21:10:04.241420 23156 model_lib_v2.py:708] {'Loss/classification_loss': 0.10819013,
#  'Loss/localization_loss': 0.033523697,
#  'Loss/regularization_loss': 0.14001691,
#  'Loss/total_loss': 0.28173074,
#  'learning_rate': 0.07779749}
# INFO:tensorflow:Step 6300 per-step time 0.318s
# I0512 21:10:35.995608 23156 model_lib_v2.py:705] Step 6300 per-step time 0.318s
# INFO:tensorflow:{'Loss/classification_loss': 0.14006236,
#  'Loss/localization_loss': 0.11506056,
#  'Loss/regularization_loss': 0.13959345,
#  'Loss/total_loss': 0.39471638,
#  'learning_rate': 0.07771279}
# I0512 21:10:35.996607 23156 model_lib_v2.py:708] {'Loss/classification_loss': 0.14006236,
#  'Loss/localization_loss': 0.11506056,
#  'Loss/regularization_loss': 0.13959345,
#  'Loss/total_loss': 0.39471638,
#  'learning_rate': 0.07771279}
# INFO:tensorflow:Step 6400 per-step time 0.317s
# I0512 21:11:07.662795 23156 model_lib_v2.py:705] Step 6400 per-step time 0.317s
# INFO:tensorflow:{'Loss/classification_loss': 0.10895195,
#  'Loss/localization_loss': 0.04554818,
#  'Loss/regularization_loss': 0.13930063,
#  'Loss/total_loss': 0.29380077,
#  'learning_rate': 0.077626534}
# I0512 21:11:07.662795 23156 model_lib_v2.py:708] {'Loss/classification_loss': 0.10895195,
#  'Loss/localization_loss': 0.04554818,
#  'Loss/regularization_loss': 0.13930063,
#  'Loss/total_loss': 0.29380077,
#  'learning_rate': 0.077626534}
# INFO:tensorflow:Step 6500 per-step time 0.345s
# I0512 21:11:42.159608 23156 model_lib_v2.py:705] Step 6500 per-step time 0.345s
# INFO:tensorflow:{'Loss/classification_loss': 0.19986013,
#  'Loss/localization_loss': 0.12150068,
#  'Loss/regularization_loss': 0.13889359,
#  'Loss/total_loss': 0.46025437,
#  'learning_rate': 0.077538736}
# I0512 21:11:42.160608 23156 model_lib_v2.py:708] {'Loss/classification_loss': 0.19986013,
#  'Loss/localization_loss': 0.12150068,
#  'Loss/regularization_loss': 0.13889359,
#  'Loss/total_loss': 0.46025437,
#  'learning_rate': 0.077538736}
# INFO:tensorflow:Step 6600 per-step time 0.311s
# I0512 21:12:13.273656 23156 model_lib_v2.py:705] Step 6600 per-step time 0.311s
# INFO:tensorflow:{'Loss/classification_loss': 0.12885365,
#  'Loss/localization_loss': 0.06866144,
#  'Loss/regularization_loss': 0.13857858,
#  'Loss/total_loss': 0.33609366,
#  'learning_rate': 0.077449396}
# I0512 21:12:13.274657 23156 model_lib_v2.py:708] {'Loss/classification_loss': 0.12885365,
#  'Loss/localization_loss': 0.06866144,
#  'Loss/regularization_loss': 0.13857858,
#  'Loss/total_loss': 0.33609366,
#  'learning_rate': 0.077449396}
# INFO:tensorflow:Step 6700 per-step time 0.336s
# I0512 21:12:46.855278 23156 model_lib_v2.py:705] Step 6700 per-step time 0.336s
# INFO:tensorflow:{'Loss/classification_loss': 0.08260662,
#  'Loss/localization_loss': 0.043955773,
#  'Loss/regularization_loss': 0.1381286,
#  'Loss/total_loss': 0.264691,
#  'learning_rate': 0.077358514}
# I0512 21:12:46.856287 23156 model_lib_v2.py:708] {'Loss/classification_loss': 0.08260662,
# ...
#  'Loss/localization_loss': 0.08889608,
#  'Loss/regularization_loss': 0.08465719,
#  'Loss/total_loss': 0.39128873,
#  'learning_rate': 0.048400067}
# INFO:tensorflow:Step 22300 per-step time 0.318s
# I0512 22:36:54.492972 23156 model_lib_v2.py:705] Step 22300 per-step time 0.318s
# INFO:tensorflow:{'Loss/classification_loss': 0.06770225,
#  'Loss/localization_loss': 0.0150613515,
#  'Loss/regularization_loss': 0.08440408,
#  'Loss/total_loss': 0.16716768,
#  'learning_rate': 0.048149157}
# I0512 22:36:54.492972 23156 model_lib_v2.py:708] {'Loss/classification_loss': 0.06770225,
#  'Loss/localization_loss': 0.0150613515,
#  'Loss/regularization_loss': 0.08440408,
#  'Loss/total_loss': 0.16716768,
#  'learning_rate': 0.048149157}
# INFO:tensorflow:Step 22400 per-step time 0.335s
# I0512 22:37:27.943549 23156 model_lib_v2.py:705] Step 22400 per-step time 0.335s
# INFO:tensorflow:{'Loss/classification_loss': 0.03837909,
#  'Loss/localization_loss': 0.009249216,
#  'Loss/regularization_loss': 0.08414761,
#  'Loss/total_loss': 0.13177592,
#  'learning_rate': 0.04789791}
# I0512 22:37:27.944548 23156 model_lib_v2.py:708] {'Loss/classification_loss': 0.03837909,
#  'Loss/localization_loss': 0.009249216,
#  'Loss/regularization_loss': 0.08414761,
#  'Loss/total_loss': 0.13177592,
#  'learning_rate': 0.04789791}
# INFO:tensorflow:Step 22500 per-step time 0.307s
# I0512 22:37:58.657512 23156 model_lib_v2.py:705] Step 22500 per-step time 0.307s
# INFO:tensorflow:{'Loss/classification_loss': 0.044673465,
#  'Loss/localization_loss': 0.007921287,
#  'Loss/regularization_loss': 0.0838903,
#  'Loss/total_loss': 0.13648504,
#  'learning_rate': 0.04764634}
# I0512 22:37:58.657512 23156 model_lib_v2.py:708] {'Loss/classification_loss': 0.044673465,
#  'Loss/localization_loss': 0.007921287,
#  'Loss/regularization_loss': 0.0838903,
#  'Loss/total_loss': 0.13648504,
#  'learning_rate': 0.04764634}
# INFO:tensorflow:Step 22600 per-step time 0.300s
# I0512 22:38:28.640307 23156 model_lib_v2.py:705] Step 22600 per-step time 0.300s
# INFO:tensorflow:{'Loss/classification_loss': 0.025787415,
#  'Loss/localization_loss': 0.0082579935,
#  'Loss/regularization_loss': 0.08363465,
#  'Loss/total_loss': 0.11768006,
#  'learning_rate': 0.047394462}
# I0512 22:38:28.640307 23156 model_lib_v2.py:708] {'Loss/classification_loss': 0.025787415,
#  'Loss/localization_loss': 0.0082579935,
#  'Loss/regularization_loss': 0.08363465,
#  'Loss/total_loss': 0.11768006,
#  'learning_rate': 0.047394462}
# INFO:tensorflow:Step 22700 per-step time 0.335s
# I0512 22:39:02.059877 23156 model_lib_v2.py:705] Step 22700 per-step time 0.335s
# INFO:tensorflow:{'Loss/classification_loss': 0.047713097,
#  'Loss/localization_loss': 0.010315892,
#  'Loss/regularization_loss': 0.08338126,
#  'Loss/total_loss': 0.14141025,
#  'learning_rate': 0.04714227}
# I0512 22:39:02.060877 23156 model_lib_v2.py:708] {'Loss/classification_loss': 0.047713097,
#  'Loss/localization_loss': 0.010315892,
#  'Loss/regularization_loss': 0.08338126,
#  'Loss/total_loss': 0.14141025,
#  'learning_rate': 0.04714227}
# INFO:tensorflow:Step 22800 per-step time 0.320s
# I0512 22:39:34.086147 23156 model_lib_v2.py:705] Step 22800 per-step time 0.320s
# INFO:tensorflow:{'Loss/classification_loss': 0.038530175,
#  'Loss/localization_loss': 0.009773076,
#  'Loss/regularization_loss': 0.08313693,
#  'Loss/total_loss': 0.13144018,
#  'learning_rate': 0.046889797}
# I0512 22:39:34.087148 23156 model_lib_v2.py:708] {'Loss/classification_loss': 0.038530175,
#  'Loss/localization_loss': 0.009773076,
#  'Loss/regularization_loss': 0.08313693,
#  'Loss/total_loss': 0.13144018,
#  'learning_rate': 0.046889797}
# INFO:tensorflow:Step 22900 per-step time 0.317s
# I0512 22:40:05.712306 23156 model_lib_v2.py:705] Step 22900 per-step time 0.317s
# INFO:tensorflow:{'Loss/classification_loss': 0.031098865,
#  'Loss/localization_loss': 0.02632155,
#  'Loss/regularization_loss': 0.08288766,
#  'Loss/total_loss': 0.14030808,
#  'learning_rate': 0.046637025}
# I0512 22:40:05.712306 23156 model_lib_v2.py:708] {'Loss/classification_loss': 0.031098865,
#  'Loss/localization_loss': 0.02632155,
#  'Loss/regularization_loss': 0.08288766,
#  'Loss/total_loss': 0.14030808,
#  'learning_rate': 0.046637025}
# INFO:tensorflow:Step 23000 per-step time 0.345s
# I0512 22:40:40.143074 23156 model_lib_v2.py:705] Step 23000 per-step time 0.345s
# INFO:tensorflow:{'Loss/classification_loss': 0.042324077,
#  'Loss/localization_loss': 0.013797387,
#  'Loss/regularization_loss': 0.08265339,
#  'Loss/total_loss': 0.13877486,
#  'learning_rate': 0.046383996}
# I0512 22:40:40.144075 23156 model_lib_v2.py:708] {'Loss/classification_loss': 0.042324077,
#  'Loss/localization_loss': 0.013797387,
#  'Loss/regularization_loss': 0.08265339,
#  'Loss/total_loss': 0.13877486,
#  'learning_rate': 0.046383996}
# INFO:tensorflow:Step 23100 per-step time 0.343s
# I0512 22:41:14.463915 23156 model_lib_v2.py:705] Step 23100 per-step time 0.343s
# INFO:tensorflow:{'Loss/classification_loss': 0.038849108,
#  'Loss/localization_loss': 0.022323644,
#  'Loss/regularization_loss': 0.082410574,
#  'Loss/total_loss': 0.14358333,
#  'learning_rate': 0.04613069}
# I0512 22:41:14.465923 23156 model_lib_v2.py:708] {'Loss/classification_loss': 0.038849108,
#  'Loss/localization_loss': 0.022323644,
#  'Loss/regularization_loss': 0.082410574,
#  'Loss/total_loss': 0.14358333,
#  'learning_rate': 0.04613069}
# INFO:tensorflow:Step 23200 per-step time 0.307s
# I0512 22:41:45.177875 23156 model_lib_v2.py:705] Step 23200 per-step time 0.307s
# INFO:tensorflow:{'Loss/classification_loss': 0.06625255,
#  'Loss/localization_loss': 0.010844264,
#  'Loss/regularization_loss': 0.082167946,
#  'Loss/total_loss': 0.15926477,
#  'learning_rate': 0.04587714}
# I0512 22:41:45.178876 23156 model_lib_v2.py:708] {'Loss/classification_loss': 0.06625255,
#  'Loss/localization_loss': 0.010844264,
#  'Loss/regularization_loss': 0.082167946,
#  'Loss/total_loss': 0.15926477,
#  'learning_rate': 0.04587714}
# INFO:tensorflow:Step 23300 per-step time 0.326s
# I0512 22:42:17.841285 23156 model_lib_v2.py:705] Step 23300 per-step time 0.326s
# INFO:tensorflow:{'Loss/classification_loss': 0.05605092,
#  'Loss/localization_loss': 0.006576982,
#  'Loss/regularization_loss': 0.081934564,
#  'Loss/total_loss': 0.14456247,
#  'learning_rate': 0.045623355}
# I0512 22:42:17.842280 23156 model_lib_v2.py:708] {'Loss/classification_loss': 0.05605092,
#  'Loss/localization_loss': 0.006576982,
#  'Loss/regularization_loss': 0.081934564,
#  'Loss/total_loss': 0.14456247,
#  'learning_rate': 0.045623355}
# INFO:tensorflow:Step 23400 per-step time 0.310s
# I0512 22:42:48.783290 23156 model_lib_v2.py:705] Step 23400 per-step time 0.310s
# INFO:tensorflow:{'Loss/classification_loss': 0.055704337,
#  'Loss/localization_loss': 0.025822677,
#  'Loss/regularization_loss': 0.08171144,
#  'Loss/total_loss': 0.16323845,
#  'learning_rate': 0.045369323}
# I0512 22:42:48.784291 23156 model_lib_v2.py:708] {'Loss/classification_loss': 0.055704337,
#  'Loss/localization_loss': 0.025822677,
#  'Loss/regularization_loss': 0.08171144,
#  'Loss/total_loss': 0.16323845,
#  'learning_rate': 0.045369323}
# INFO:tensorflow:Step 23500 per-step time 0.317s
# I0512 22:43:20.480482 23156 model_lib_v2.py:705] Step 23500 per-step time 0.317s
# INFO:tensorflow:{'Loss/classification_loss': 0.038634565,
#  'Loss/localization_loss': 0.014006059,
#  'Loss/regularization_loss': 0.08148518,
#  'Loss/total_loss': 0.1341258,
#  'learning_rate': 0.045115083}
# I0512 22:43:20.481482 23156 model_lib_v2.py:708] {'Loss/classification_loss': 0.038634565,
#  'Loss/localization_loss': 0.014006059,
#  'Loss/regularization_loss': 0.08148518,
#  'Loss/total_loss': 0.1341258,
#  'learning_rate': 0.045115083}
# INFO:tensorflow:Step 23600 per-step time 0.318s
# I0512 22:43:52.325700 23156 model_lib_v2.py:705] Step 23600 per-step time 0.318s
# INFO:tensorflow:{'Loss/classification_loss': 0.06263472,
#  'Loss/localization_loss': 0.013246329,
#  'Loss/regularization_loss': 0.081258684,
#  'Loss/total_loss': 0.15713973,
#  'learning_rate': 0.044860635}
# I0512 22:43:52.326698 23156 model_lib_v2.py:708] {'Loss/classification_loss': 0.06263472,
#  'Loss/localization_loss': 0.013246329,
#  'Loss/regularization_loss': 0.081258684,
#  'Loss/total_loss': 0.15713973,
#  'learning_rate': 0.044860635}
# INFO:tensorflow:Step 23700 per-step time 0.327s
# I0512 22:44:24.969090 23156 model_lib_v2.py:705] Step 23700 per-step time 0.327s
# INFO:tensorflow:{'Loss/classification_loss': 0.06325544,
#  'Loss/localization_loss': 0.025380837,
#  'Loss/regularization_loss': 0.08103522,
#  'Loss/total_loss': 0.16967149,
#  'learning_rate': 0.044605974}
# I0512 22:44:24.970091 23156 model_lib_v2.py:708] {'Loss/classification_loss': 0.06325544,
#  'Loss/localization_loss': 0.025380837,
#  'Loss/regularization_loss': 0.08103522,
#  'Loss/total_loss': 0.16967149,
#  'learning_rate': 0.044605974}
# INFO:tensorflow:Step 23800 per-step time 0.338s
# I0512 22:44:58.727745 23156 model_lib_v2.py:705] Step 23800 per-step time 0.338s
# INFO:tensorflow:{'Loss/classification_loss': 0.052024163,
#  'Loss/localization_loss': 0.013451511,
#  'Loss/regularization_loss': 0.080808714,
#  'Loss/total_loss': 0.14628439,
#  'learning_rate': 0.044351134}
# I0512 22:44:58.728744 23156 model_lib_v2.py:708] {'Loss/classification_loss': 0.052024163,
#  'Loss/localization_loss': 0.013451511,
#  'Loss/regularization_loss': 0.080808714,
#  'Loss/total_loss': 0.14628439,
#  'learning_rate': 0.044351134}
# INFO:tensorflow:Step 23900 per-step time 0.310s
# I0512 22:45:29.737773 23156 model_lib_v2.py:705] Step 23900 per-step time 0.310s
# INFO:tensorflow:{'Loss/classification_loss': 0.031019654,
#  'Loss/localization_loss': 0.010549787,
#  'Loss/regularization_loss': 0.08057239,
#  'Loss/total_loss': 0.12214183,
#  'learning_rate': 0.044096105}
# I0512 22:45:29.738773 23156 model_lib_v2.py:708] {'Loss/classification_loss': 0.031019654,
#  'Loss/localization_loss': 0.010549787,
#  'Loss/regularization_loss': 0.08057239,
#  'Loss/total_loss': 0.12214183,
#  'learning_rate': 0.044096105}
# INFO:tensorflow:Step 24000 per-step time 0.340s
# I0512 22:46:03.696465 23156 model_lib_v2.py:705] Step 24000 per-step time 0.340s
# INFO:tensorflow:{'Loss/classification_loss': 0.032496933,
#  'Loss/localization_loss': 0.010233299,
#  'Loss/regularization_loss': 0.08034795,
#  'Loss/total_loss': 0.12307818,
#  'learning_rate': 0.043840922}
# I0512 22:46:03.696465 23156 model_lib_v2.py:708] {'Loss/classification_loss': 0.032496933,
#  'Loss/localization_loss': 0.010233299,
#  'Loss/regularization_loss': 0.08034795,
#  'Loss/total_loss': 0.12307818,
#  'learning_rate': 0.043840922}
# INFO:tensorflow:Step 24100 per-step time 0.332s
# I0512 22:46:37.009025 23156 model_lib_v2.py:705] Step 24100 per-step time 0.332s
# INFO:tensorflow:{'Loss/classification_loss': 0.04457338,
#  'Loss/localization_loss': 0.01149097,
#  'Loss/regularization_loss': 0.080129616,
#  'Loss/total_loss': 0.13619396,
#  'learning_rate': 0.043585572}
# I0512 22:46:37.011025 23156 model_lib_v2.py:708] {'Loss/classification_loss': 0.04457338,
#  'Loss/localization_loss': 0.01149097,
#  'Loss/regularization_loss': 0.080129616,
#  'Loss/total_loss': 0.13619396,
#  'learning_rate': 0.043585572}
# INFO:tensorflow:Step 24200 per-step time 0.328s
# I0512 22:47:09.801249 23156 model_lib_v2.py:705] Step 24200 per-step time 0.328s
# INFO:tensorflow:{'Loss/classification_loss': 0.056989074,
#  'Loss/localization_loss': 0.0066282493,
#  'Loss/regularization_loss': 0.07992915,
#  'Loss/total_loss': 0.14354648,
#  'learning_rate': 0.043330073}
# I0512 22:47:09.802249 23156 model_lib_v2.py:708] {'Loss/classification_loss': 0.056989074,
#  'Loss/localization_loss': 0.0066282493,
#  'Loss/regularization_loss': 0.07992915,
#  'Loss/total_loss': 0.14354648,
#  'learning_rate': 0.043330073}
# INFO:tensorflow:Step 24300 per-step time 0.334s
# I0512 22:47:43.096794 23156 model_lib_v2.py:705] Step 24300 per-step time 0.334s
# INFO:tensorflow:{'Loss/classification_loss': 0.040462364,
#  'Loss/localization_loss': 0.00982433,
#  'Loss/regularization_loss': 0.07972616,
#  'Loss/total_loss': 0.13001285,
#  'learning_rate': 0.04307444}
# I0512 22:47:43.097794 23156 model_lib_v2.py:708] {'Loss/classification_loss': 0.040462364,
#  'Loss/localization_loss': 0.00982433,
#  'Loss/regularization_loss': 0.07972616,
#  'Loss/total_loss': 0.13001285,
#  'learning_rate': 0.04307444}
# INFO:tensorflow:Step 24400 per-step time 0.302s
# I0512 22:48:13.266630 23156 model_lib_v2.py:705] Step 24400 per-step time 0.302s
# INFO:tensorflow:{'Loss/classification_loss': 0.05637621,
#  'Loss/localization_loss': 0.007902444,
#  'Loss/regularization_loss': 0.07951204,
#  'Loss/total_loss': 0.14379069,
#  'learning_rate': 0.04281868}
# I0512 22:48:13.266630 23156 model_lib_v2.py:708] {'Loss/classification_loss': 0.05637621,
#  'Loss/localization_loss': 0.007902444,
#  'Loss/regularization_loss': 0.07951204,
#  'Loss/total_loss': 0.14379069,
#  'learning_rate': 0.04281868}
# INFO:tensorflow:Step 24500 per-step time 0.295s
# I0512 22:48:42.829852 23156 model_lib_v2.py:705] Step 24500 per-step time 0.295s
# INFO:tensorflow:{'Loss/classification_loss': 0.019751502,
#  'Loss/localization_loss': 0.011153943,
#  'Loss/regularization_loss': 0.07929853,
#  'Loss/total_loss': 0.11020398,
#  'learning_rate': 0.042562805}
# I0512 22:48:42.829852 23156 model_lib_v2.py:708] {'Loss/classification_loss': 0.019751502,
#  'Loss/localization_loss': 0.011153943,
#  'Loss/regularization_loss': 0.07929853,
#  'Loss/total_loss': 0.11020398,
#  'learning_rate': 0.042562805}
# INFO:tensorflow:Step 24600 per-step time 0.329s
# I0512 22:49:15.696317 23156 model_lib_v2.py:705] Step 24600 per-step time 0.329s
# INFO:tensorflow:{'Loss/classification_loss': 0.08155812,
#  'Loss/localization_loss': 0.013885018,
#  'Loss/regularization_loss': 0.07909025,
#  'Loss/total_loss': 0.1745334,
#  'learning_rate': 0.04230683}
# I0512 22:49:15.697306 23156 model_lib_v2.py:708] {'Loss/classification_loss': 0.08155812,
#  'Loss/localization_loss': 0.013885018,
#  'Loss/regularization_loss': 0.07909025,
#  'Loss/total_loss': 0.1745334,
#  'learning_rate': 0.04230683}
# INFO:tensorflow:Step 24700 per-step time 0.313s
# I0512 22:49:47.059413 23156 model_lib_v2.py:705] Step 24700 per-step time 0.313s
# INFO:tensorflow:{'Loss/classification_loss': 0.029268669,
#  'Loss/localization_loss': 0.019341215,
#  'Loss/regularization_loss': 0.07889171,
#  'Loss/total_loss': 0.12750159,
#  'learning_rate': 0.042050745}
# I0512 22:49:47.061413 23156 model_lib_v2.py:708] {'Loss/classification_loss': 0.029268669,
#  'Loss/localization_loss': 0.019341215,
#  'Loss/regularization_loss': 0.07889171,
#  'Loss/total_loss': 0.12750159,
#  'learning_rate': 0.042050745}
# INFO:tensorflow:Step 24800 per-step time 0.341s
# I0512 22:50:21.112130 23156 model_lib_v2.py:705] Step 24800 per-step time 0.341s
# INFO:tensorflow:{'Loss/classification_loss': 0.067712024,
#  'Loss/localization_loss': 0.023852225,
#  'Loss/regularization_loss': 0.0786986,
#  'Loss/total_loss': 0.17026284,
#  'learning_rate': 0.04179459}
# I0512 22:50:21.112130 23156 model_lib_v2.py:708] {'Loss/classification_loss': 0.067712024,
#  'Loss/localization_loss': 0.023852225,
#  'Loss/regularization_loss': 0.0786986,
#  'Loss/total_loss': 0.17026284,
#  'learning_rate': 0.04179459}
# INFO:tensorflow:Step 24900 per-step time 0.336s
# I0512 22:50:54.691282 23156 model_lib_v2.py:705] Step 24900 per-step time 0.336s
# INFO:tensorflow:{'Loss/classification_loss': 0.028673457,
#  'Loss/localization_loss': 0.0041511497,
#  'Loss/regularization_loss': 0.07849138,
#  'Loss/total_loss': 0.11131599,
#  'learning_rate': 0.04153835}
# I0512 22:50:54.692281 23156 model_lib_v2.py:708] {'Loss/classification_loss': 0.028673457,
#  'Loss/localization_loss': 0.0041511497,
#  'Loss/regularization_loss': 0.07849138,
#  'Loss/total_loss': 0.11131599,
#  'learning_rate': 0.04153835}
# INFO:tensorflow:Step 25000 per-step time 0.302s
# I0512 22:51:24.953146 23156 model_lib_v2.py:705] Step 25000 per-step time 0.302s
# INFO:tensorflow:{'Loss/classification_loss': 0.028413549,
#  'Loss/localization_loss': 0.0050286185,
#  'Loss/regularization_loss': 0.07827807,
#  'Loss/total_loss': 0.11172024,
#  'learning_rate': 0.04128206}
# I0512 22:51:24.953146 23156 model_lib_v2.py:708] {'Loss/classification_loss': 0.028413549,
#  'Loss/localization_loss': 0.0050286185,
#  'Loss/regularization_loss': 0.07827807,
#  'Loss/total_loss': 0.11172024,
#  'learning_rate': 0.04128206}

# %%
command = "python {} --model_dir={} --pipeline_config_path={} --checkpoint_dir={}".format(TRAINING_SCRIPT, paths['CHECKPOINT_PATH'],files['PIPELINE_CONFIG'], paths['CHECKPOINT_PATH'])

# %%
print(command)
# Out:
# python Tensorflow\models\research\object_detection\model_main_tf2.py --model_dir=Tensorflow\workspace\models\my_ssd_mobnet_update --pipeline_config_path=Tensorflow\workspace\models\my_ssd_mobnet_update\pipeline.config --checkpoint_dir=Tensorflow\workspace\models\my_ssd_mobnet_update

# %%
# !{command}
# Out:
# creating index...
# index created!
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.02s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.724
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 1.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.626
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.724
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.780
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.780
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.780
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.780
# WARNING:tensorflow:Forced number of epochs for all eval validations to be 1.
# W0409 20:07:03.313636 20184 model_lib_v2.py:1089] Forced number of epochs for all eval validations to be 1.
# INFO:tensorflow:Maybe overwriting sample_1_of_n_eval_examples: None
# I0409 20:07:03.313636 20184 config_util.py:552] Maybe overwriting sample_1_of_n_eval_examples: None
# INFO:tensorflow:Maybe overwriting use_bfloat16: False
# I0409 20:07:03.314637 20184 config_util.py:552] Maybe overwriting use_bfloat16: False
# INFO:tensorflow:Maybe overwriting eval_num_epochs: 1
# I0409 20:07:03.314637 20184 config_util.py:552] Maybe overwriting eval_num_epochs: 1
# WARNING:tensorflow:Expected number of evaluation epochs is 1, but instead encountered `eval_on_train_input_config.num_epochs` = 0. Overwriting `num_epochs` to 1.
# W0409 20:07:03.314637 20184 model_lib_v2.py:1107] Expected number of evaluation epochs is 1, but instead encountered `eval_on_train_input_config.num_epochs` = 0. Overwriting `num_epochs` to 1.
# 2022-04-09 20:07:03.318629: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX AVX2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-04-09 20:07:03.769703: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2151 MB memory:  -> device: 0, name: GeForce GTX 1650 Ti, pci bus id: 0000:01:00.0, compute capability: 7.5
# INFO:tensorflow:Reading unweighted datasets: ['Tensorflow\\workspace\\annotations\\test.record']
# I0409 20:07:03.948640 20184 dataset_builder.py:163] Reading unweighted datasets: ['Tensorflow\\workspace\\annotations\\test.record']
# INFO:tensorflow:Reading record datasets for input file: ['Tensorflow\\workspace\\annotations\\test.record']
# I0409 20:07:03.949640 20184 dataset_builder.py:80] Reading record datasets for input file: ['Tensorflow\\workspace\\annotations\\test.record']
# INFO:tensorflow:Number of filenames to read: 1
# I0409 20:07:03.949640 20184 dataset_builder.py:81] Number of filenames to read: 1
# WARNING:tensorflow:num_readers has been reduced to 1 to match input file shards.
# W0409 20:07:03.949640 20184 dataset_builder.py:87] num_readers has been reduced to 1 to match input file shards.
# WARNING:tensorflow:From C:\Programming\Hackathon-2022\hackathon\lib\site-packages\object_detection-0.1-py3.8.egg\object_detection\builders\dataset_builder.py:101: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# W0409 20:07:03.950641 20184 deprecation.py:337] From C:\Programming\Hackathon-2022\hackathon\lib\site-packages\object_detection-0.1-py3.8.egg\object_detection\builders\dataset_builder.py:101: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# WARNING:tensorflow:From C:\Programming\Hackathon-2022\hackathon\lib\site-packages\object_detection-0.1-py3.8.egg\object_detection\builders\dataset_builder.py:236: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# W0409 20:07:03.971645 20184 deprecation.py:337] From C:\Programming\Hackathon-2022\hackathon\lib\site-packages\object_detection-0.1-py3.8.egg\object_detection\builders\dataset_builder.py:236: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# WARNING:tensorflow:From C:\Programming\Hackathon-2022\hackathon\lib\site-packages\tensorflow-2.8.0-py3.8-win-amd64.egg\tensorflow\python\util\dispatch.py:1082: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# W0409 20:07:06.746294 20184 deprecation.py:337] From C:\Programming\Hackathon-2022\hackathon\lib\site-packages\tensorflow-2.8.0-py3.8-win-amd64.egg\tensorflow\python\util\dispatch.py:1082: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# WARNING:tensorflow:From C:\Programming\Hackathon-2022\hackathon\lib\site-packages\tensorflow-2.8.0-py3.8-win-amd64.egg\tensorflow\python\util\dispatch.py:1082: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W0409 20:07:07.455455 20184 deprecation.py:337] From C:\Programming\Hackathon-2022\hackathon\lib\site-packages\tensorflow-2.8.0-py3.8-win-amd64.egg\tensorflow\python\util\dispatch.py:1082: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# INFO:tensorflow:Waiting for new checkpoint at Tensorflow\workspace\models\my_ssd_mobnet_update
# I0409 20:07:09.250862 20184 checkpoint_utils.py:136] Waiting for new checkpoint at Tensorflow\workspace\models\my_ssd_mobnet_update
# INFO:tensorflow:Found new checkpoint at Tensorflow\workspace\models\my_ssd_mobnet_update\ckpt-5
# I0409 20:07:09.256863 20184 checkpoint_utils.py:145] Found new checkpoint at Tensorflow\workspace\models\my_ssd_mobnet_update\ckpt-5
# 2022-04-09 20:07:25.733403: I tensorflow/stream_executor/cuda/cuda_dnn.cc:368] Loaded cuDNN version 8100
# C:\Programming\Hackathon-2022\hackathon\lib\site-packages\keras-2.8.0-py3.8.egg\keras\backend.py:450: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn('`tf.keras.backend.set_learning_phase` is deprecated and '
# WARNING:tensorflow:From C:\Programming\Hackathon-2022\hackathon\lib\site-packages\tensorflow-2.8.0-py3.8-win-amd64.egg\tensorflow\python\util\dispatch.py:1082: to_int64 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W0409 20:07:27.597329 20184 deprecation.py:337] From C:\Programming\Hackathon-2022\hackathon\lib\site-packages\tensorflow-2.8.0-py3.8-win-amd64.egg\tensorflow\python\util\dispatch.py:1082: to_int64 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# INFO:tensorflow:Finished eval step 0
# I0409 20:07:27.607331 20184 model_lib_v2.py:966] Finished eval step 0
# WARNING:tensorflow:From C:\Programming\Hackathon-2022\hackathon\lib\site-packages\tensorflow-2.8.0-py3.8-win-amd64.egg\tensorflow\python\autograph\impl\api.py:459: py_func (from tensorflow.python.ops.script_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# tf.py_func is deprecated in TF V2. Instead, there are two
#     options available in V2.
#     - tf.py_function takes a python function which manipulates tf eager
#     tensors instead of numpy arrays. It's easy to convert a tf eager tensor to
#     an ndarray (just call tensor.numpy()) but having access to eager tensors
#     means `tf.py_function`s can use accelerators such as GPUs as well as
#     being differentiable using a gradient tape.
#     - tf.numpy_function maintains the semantics of the deprecated tf.py_func
#     (it is not differentiable, and manipulates numpy arrays). It drops the
#     stateful argument making all functions stateful.
#
# W0409 20:07:27.725502 20184 deprecation.py:337] From C:\Programming\Hackathon-2022\hackathon\lib\site-packages\tensorflow-2.8.0-py3.8-win-amd64.egg\tensorflow\python\autograph\impl\api.py:459: py_func (from tensorflow.python.ops.script_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# tf.py_func is deprecated in TF V2. Instead, there are two
#     options available in V2.
#     - tf.py_function takes a python function which manipulates tf eager
#     tensors instead of numpy arrays. It's easy to convert a tf eager tensor to
#     an ndarray (just call tensor.numpy()) but having access to eager tensors
#     means `tf.py_function`s can use accelerators such as GPUs as well as
#     being differentiable using a gradient tape.
#     - tf.numpy_function maintains the semantics of the deprecated tf.py_func
#     (it is not differentiable, and manipulates numpy arrays). It drops the
#     stateful argument making all functions stateful.
#
# INFO:tensorflow:Performing evaluation on 7 images.
# I0409 20:07:29.164896 20184 coco_evaluation.py:293] Performing evaluation on 7 images.
# INFO:tensorflow:Loading and preparing annotation results...
# I0409 20:07:29.165895 20184 coco_tools.py:116] Loading and preparing annotation results...
# INFO:tensorflow:DONE (t=0.00s)
# I0409 20:07:29.165895 20184 coco_tools.py:138] DONE (t=0.00s)
# INFO:tensorflow:Eval metrics at step 4000
# I0409 20:07:29.196928 20184 model_lib_v2.py:1015] Eval metrics at step 4000
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP: 0.723515
# I0409 20:07:29.199928 20184 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP: 0.723515
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP@.50IOU: 1.000000
# I0409 20:07:29.200936 20184 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP@.50IOU: 1.000000
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP@.75IOU: 0.626238
# I0409 20:07:29.201936 20184 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP@.75IOU: 0.626238
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP (small): -1.000000
# I0409 20:07:29.209946 20184 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP (small): -1.000000
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP (medium): -1.000000
# I0409 20:07:29.210947 20184 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP (medium): -1.000000
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP (large): 0.723515
# I0409 20:07:29.211947 20184 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP (large): 0.723515
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@1: 0.780000
# I0409 20:07:29.213948 20184 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@1: 0.780000
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@10: 0.780000
# I0409 20:07:29.213948 20184 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@10: 0.780000
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100: 0.780000
# I0409 20:07:29.214948 20184 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100: 0.780000
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100 (small): -1.000000
# I0409 20:07:29.215948 20184 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100 (small): -1.000000
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100 (medium): -1.000000
# I0409 20:07:29.216948 20184 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100 (medium): -1.000000
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100 (large): 0.780000
# I0409 20:07:29.217949 20184 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100 (large): 0.780000
# INFO:tensorflow:	+ Loss/localization_loss: 0.119771
# I0409 20:07:29.217949 20184 model_lib_v2.py:1018] 	+ Loss/localization_loss: 0.119771
# INFO:tensorflow:	+ Loss/classification_loss: 0.356838
# I0409 20:07:29.218949 20184 model_lib_v2.py:1018] 	+ Loss/classification_loss: 0.356838
# INFO:tensorflow:	+ Loss/regularization_loss: 0.124898
# I0409 20:07:29.220949 20184 model_lib_v2.py:1018] 	+ Loss/regularization_loss: 0.124898
# INFO:tensorflow:	+ Loss/total_loss: 0.601508
# I0409 20:07:29.221950 20184 model_lib_v2.py:1018] 	+ Loss/total_loss: 0.601508
# INFO:tensorflow:Waiting for new checkpoint at Tensorflow\workspace\models\my_ssd_mobnet_update
# I0409 20:12:09.260097 20184 checkpoint_utils.py:136] Waiting for new checkpoint at Tensorflow\workspace\models\my_ssd_mobnet_update
# INFO:tensorflow:Timed-out waiting for a checkpoint.
# I0409 21:12:08.404346 20184 checkpoint_utils.py:199] Timed-out waiting for a checkpoint.

# %%
import os
import tensorflow as tf
from object_detection.utils import label_map_util
from object_detection.utils import visualization_utils as viz_utils
from object_detection.builders import model_builder
from object_detection.utils import config_util

# %%
# Load pipeline config and build a detection model
configs = config_util.get_configs_from_pipeline_file(files['PIPELINE_CONFIG'])
detection_model = model_builder.build(model_config=configs['model'], is_training=False)

# Restore checkpoint
ckpt = tf.compat.v2.train.Checkpoint(model=detection_model)
ckpt.restore(os.path.join(paths['CHECKPOINT_PATH'], 'ckpt-26')).expect_partial()

@tf.function
def detect_fn(image):
    image, shapes = detection_model.preprocess(image)
    prediction_dict = detection_model.predict(image, shapes)
    detections = detection_model.postprocess(prediction_dict, shapes)
    return detections

# %%
category_index = label_map_util.create_category_index_from_labelmap(files['LABELMAP'])

# %%
IMAGE_PATH = os.path.join(paths['IMAGE_PATH'], 'NotUsed', 'Four.add9f38d-d200-11ec-8886-3c7c3fea4b04.jpg')

# %%
IMAGE_PATH
# Out:
# 'Tensorflow\\workspace\\images\\NotUsed\\Four.add9f38d-d200-11ec-8886-3c7c3fea4b04.jpg'

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import tkinter
import matplotlib
matplotlib.use('TkAgg')

# %%
# IMAGE

# %%
img = cv2.imread(IMAGE_PATH)
image_np = np.array(img)

input_tensor = tf.convert_to_tensor(np.expand_dims(image_np, 0), dtype=tf.float32)
detections = detect_fn(input_tensor)

num_detections = int(detections.pop('num_detections'))
detections = {key: value[0, :num_detections].numpy()
              for key, value in detections.items()}
detections['num_detections'] = num_detections

# detection_classes should be ints.
detections['detection_classes'] = detections['detection_classes'].astype(np.int64)

label_id_offset = 1
image_np_with_detections = image_np.copy()

viz_utils.visualize_boxes_and_labels_on_image_array(
            image_np_with_detections,
            detections['detection_boxes'],
            detections['detection_classes']+label_id_offset,
            detections['detection_scores'],
            category_index,
            use_normalized_coordinates=True,
            max_boxes_to_draw=5,
            min_score_thresh=.8,
            agnostic_mode=False)

plt.imshow(cv2.cvtColor(image_np_with_detections, cv2.COLOR_BGR2RGB))
plt.show()

# %%
# REAL TIME

# %%
def capture_real():
    cap = cv2.VideoCapture(0)
    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

    while cap.isOpened(): 
        ret, frame = cap.read()
        image_np = np.array(frame)

        input_tensor = tf.convert_to_tensor(np.expand_dims(image_np, 0), dtype=tf.float32)
        detections = detect_fn(input_tensor)

        num_detections = int(detections.pop('num_detections'))
        detections = {key: value[0, :num_detections].numpy()
                      for key, value in detections.items()}
        detections['num_detections'] = num_detections

        # detection_classes should be ints.
        detections['detection_classes'] = detections['detection_classes'].astype(np.int64)

        label_id_offset = 1
        image_np_with_detections = image_np.copy()

        viz_utils.visualize_boxes_and_labels_on_image_array(
                    image_np_with_detections,
                    detections['detection_boxes'],
                    detections['detection_classes']+label_id_offset,
                    detections['detection_scores'],
                    category_index,
                    use_normalized_coordinates=True,
                    max_boxes_to_draw=5,
                    min_score_thresh=.8,
                    agnostic_mode=False)

        cv2.imshow('object detection',  cv2.resize(image_np_with_detections, (800, 600)))

        if cv2.waitKey(10) & 0xFF == ord('q'):
            cap.release()
            cv2.destroyAllWindows()
            break

# %%
#Import tkinter library
from tkinter import *
#Create an instance of Tkinter frame or window
win= Tk()
win.title("Detection")
#Set the geometry of tkinter frame
win.geometry("750x250")
btn=Button(win, text="Start Capture", command=capture_real)
btn.place(x=340, y=20)
# btn.pack(ipadx=10)
win.bind('<Return>',lambda event:function())
win.mainloop()

# %%
#👩‍FREEZING THE GRAPH

# %%
# FREEZE_SCRIPT = os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection', 'exporter_main_v2.py ')

# %%
# command = "python {} --input_type=image_tensor --pipeline_config_path={} --trained_checkpoint_dir={} --output_directory={}".format(FREEZE_SCRIPT ,files['PIPELINE_CONFIG'], paths['CHECKPOINT_PATH'], paths['OUTPUT_PATH'])
# print(command)

# %%
# !{command}

# %%
#👩‍💻Conversion to TFJS

# %%
#!pip install tensorflowjs

# %%
# command = "tensorflowjs_converter --input_format=tf_saved_model --output_node_names='detection_boxes,detection_classes,detection_features,detection_multiclass_scores,detection_scores,num_detections,raw_detection_boxes,raw_detection_scores' --output_format=tfjs_graph_model --signature_name=serving_default {} {}".format(os.path.join(paths['OUTPUT_PATH'], 'saved_model'), paths['TFJS_PATH'])
# print(command)

# %%
# !{command}

# %%
# 👩‍Conversion to TFLite

# %%
# TFLITE_SCRIPT = os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection', 'export_tflite_graph_tf2.py ')
# command = "python {} --pipeline_config_path={} --trained_checkpoint_dir={} --output_directory={}".format(TFLITE_SCRIPT ,files['PIPELINE_CONFIG'], paths['CHECKPOINT_PATH'], paths['TFLITE_PATH'])
# print(command)
# !{command}

# %%
# 👩‍Saving the TFLITE FILE

# %%
# FROZEN_TFLITE_PATH = os.path.join(paths['TFLITE_PATH'], 'saved_model')
# TFLITE_MODEL = os.path.join(paths['TFLITE_PATH'], 'saved_model', 'detect.tflite')
# command = "tflite_convert \
# --saved_model_dir={} \
# --output_file={} \
# --input_shapes=1,300,300,3 \
# --input_arrays=normalized_input_image_tensor \
# --output_arrays='TFLite_Detection_PostProcess','TFLite_Detection_PostProcess:1','TFLite_Detection_PostProcess:2','TFLite_Detection_PostProcess:3' \
# --inference_type=FLOAT \
# --allow_custom_ops".format(FROZEN_TFLITE_PATH, TFLITE_MODEL, )
# print(command)

# %%
# !{command}
